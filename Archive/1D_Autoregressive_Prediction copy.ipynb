# %% [markdown]
# ### 1D Autoregressive Token prediction

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torch.nn.functional as F
import random
import matplotlib.pyplot as plt
import jax.numpy as jnp
from jax import random
import contextlib
from scipy.stats import skew, kurtosis
from statsmodels.tsa.stattools import acf, pacf

# %% [markdown]
# #### Data Preparation

# %% [markdown]
# ##### Geometric Brownian Motion Simulator
#
# $dS_t = \mu S_tdt + \sigma S_tdW_t \\$
#
# $S_0$: Initial Stock price $\\$
# $\mu$: Drift coefficient $\\$
# $\sigma$: Volatility coefficient $\\$
# $W_t$: Wiener Process (Brownian motion)

# %%
def gbm_simulator(key, S0, mu, sigma, T, dt):
    # Number of time steps
    N = int(T / dt)
    t = jnp.linspace(0, T, N)
    W = random.normal(key, (N,)) * jnp.sqrt(dt)
    
    # Wiener process
    W = jnp.cumsum(W)
    S = S0 * jnp.exp((mu - 0.5 * sigma**2) * t + sigma * W)
    return S

# Parameters for the GBM
S0 = 100.0                  # Initial stock price
mu = 0.1                    # Drift coefficient
sigma = 0.2                 # Volatility coefficient
T = 5.0                     # Total time (year)
dt = 0.005                  # Time step

# Generate random key
key = random.PRNGKey(0)

# Simulate GBM
GBM_data = gbm_simulator(key, S0, mu, sigma, T, dt)

# %%
# Plot the time series
plt.figure(figsize=(6, 3))
plt.plot(GBM_data, color ='blue')
plt.title('Simulated GBM Time Series')
plt.xlabel('Time Step (Days)')
plt.ylabel('Price')
plt.show()

# Calculate and print basic statistics
mean_price = jnp.mean(GBM_data)
std_dev_price = jnp.std(GBM_data)
print(f"Mean Price: {mean_price:.2f}")
print(f"Standard Deviation of Price: {std_dev_price:.2f}")
# Out:
# Mean Price: 136.36
# Standard Deviation of Price: 17.87

# %% [markdown]
# Discretizng data

# %%
data = np.array(GBM_data)
bin_start = 30
bin_stop = 180
num_bins = 30
bin_edges = np.linspace(bin_start, bin_stop, num_bins + 1)
# Tokenize the data
tokenized_data = np.digitize(GBM_data, bins=bin_edges, right=False) - 1
# Clip any prices below 30 to the first bin and above 170 to the last bin (Token 0 to 29)
tokenized_data = np.clip(tokenized_data, 0, num_bins - 1)
# Train / Test Split
train_data_temp, temp_data = train_test_split(tokenized_data, train_size=0.6, shuffle=False)
val_data_temp, test_data_temp = train_test_split(temp_data, test_size=0.5, shuffle=False)

def prep_data(seq_len, start_indexes, data):
    final_list = []
    for i in start_indexes:
        final_list.append(data[i:i+seq_len])
    return final_list

# %%
class LSTMModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim):
        super(LSTMModel, self).__init__()
        # Embedding Layer
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        # LSTM Layer
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True)
        # Fully Connected Layer
        self.fc = nn.Linear(hidden_dim, output_dim)
    
    def forward(self, x, hidden=None):
        # A sequence of 50 tokens is passed to the embedding layer and we get the embeddings for each token (dimension: 32)
        embedded = self.embedding(x)                            # Shape: [batch_size, sequence_length, embedding_dim] [1, 50, 32]
        # LSTM layer
        lstm_out, (h_n, c_n) = self.lstm(embedded, hidden)      # Input: 50 tokens, Output: 50 hidden states with dimension 128
        # Apply fully connected layer to each time step
        logits = self.fc(lstm_out)                              # Shape: [batch_size, sequence_length, output_dim]
        
        return logits, hidden                                   # Return predictions for each time step

# %%
# seq_len = 50
# val_data = []
# for i in range(len(val_data_temp) // seq_len):
#     start_idx = i * seq_len
#     end_idx = start_idx + seq_len
#     val_data.append(val_data_temp[start_idx:end_idx])

# %%
seq_len = 50
val_n_seq = 100
start_val_idx = np.random.choice(range(len(val_data_temp)-seq_len), size=val_n_seq, replace=True)
val_data = prep_data(seq_len=seq_len, start_indexes=start_val_idx, data=val_data_temp)

# %% [markdown]
# Loss function and training

# %%
model = LSTMModel(vocab_size=num_bins, embedding_dim=32, hidden_dim=64, output_dim=num_bins)

# Loss function
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# Training

train_n_seq = 10
num_epochs = 300
train_losses = []
validation_losses = []

best_val_loss = float('inf')

for epoch in range(num_epochs):
    
    start_train_idx = np.random.choice(range(len(train_data_temp)-seq_len), size=train_n_seq, replace=True)
    train_data = prep_data(seq_len=seq_len, start_indexes=start_train_idx, data=train_data_temp)
    
    ## TRAINING
    model.train()
    train_loss = 0
    for sequence in train_data:
        
        optimizer.zero_grad()

        sequence_input = torch.tensor(sequence[:-1]).unsqueeze(0)   # Exclude last token
        targets = torch.tensor(sequence[1:]).unsqueeze(0)           # Exclude first token

        # Shape: [1, sequence_length-1, unique_tokens]
        logits, _ = model(sequence_input)                              # [Token 1, Token 2, ..., Token 49]
        # Reshape logits to combine batch and sequence dimensions
        logits = logits.view(-1, logits.size(-1))                   # Shape: [1*49, 30] -> [49, 30]
        targets = targets.view(-1)                                  # Flatten targets to shape [49]
        # Average loss across all 49 tokens
        loss = criterion(logits, targets)
        train_loss += loss.item()

        # Backward pass and optimization
        loss.backward()
        optimizer.step()

    avg_train_loss = train_loss/len(train_data)
    train_losses.append(avg_train_loss)
    print(f"Epoch {epoch} - Avg Loss per sequence: {avg_train_loss:.4f}")

    ## VALIDATION
    model.eval()
    validation_loss = 0

    # No weight updates
    with torch.no_grad():
        for sequence in val_data:
            sequence_input = torch.tensor(sequence[:-1]).unsqueeze(0)   # Exclude last token
            targets = torch.tensor(sequence[1:]).unsqueeze(0)           # Exclude first token

            logits, _ = model(sequence_input)  # Forward pass
            logits = logits.view(-1, logits.size(-1))  # Shape: [49, 30]
            targets = targets.view(-1)  # Shape: [49]                        
            loss = criterion(logits, targets)
            validation_loss += loss.item()
    
    avg_val_loss = validation_loss / len(val_data)
    validation_losses.append(avg_val_loss)

    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        torch.save(model.state_dict(), 'best_model.pth')

    print(f"Epoch {epoch}, Validation Loss: {avg_val_loss:.4f}")

# Save model weights after training/validation
torch.save(model.state_dict(), 'model_weights.pth')
# Out:
# Epoch 0 - Avg Loss per sequence: 3.3819
# Epoch 0, Validation Loss: 3.3637
# Epoch 1 - Avg Loss per sequence: 3.2311
# Epoch 1, Validation Loss: 3.2240
# Epoch 2 - Avg Loss per sequence: 3.0441
# Epoch 2, Validation Loss: 2.9698
# Epoch 3 - Avg Loss per sequence: 2.8707
# Epoch 3, Validation Loss: 2.6045
# Epoch 4 - Avg Loss per sequence: 2.5298
# Epoch 4, Validation Loss: 2.1886
# Epoch 5 - Avg Loss per sequence: 2.1604
# Epoch 5, Validation Loss: 1.7812
# Epoch 6 - Avg Loss per sequence: 1.9240
# Epoch 6, Validation Loss: 1.5994
# Epoch 7 - Avg Loss per sequence: 1.7424
# Epoch 7, Validation Loss: 1.4809
# Epoch 8 - Avg Loss per sequence: 1.5005
# Epoch 8, Validation Loss: 1.4451
# Epoch 9 - Avg Loss per sequence: 1.4964
# Epoch 9, Validation Loss: 1.3677
# Epoch 10 - Avg Loss per sequence: 1.2749
# Epoch 10, Validation Loss: 1.3259
# Epoch 11 - Avg Loss per sequence: 1.2394
# Epoch 11, Validation Loss: 1.2848
# Epoch 12 - Avg Loss per sequence: 1.1392
# Epoch 12, Validation Loss: 1.2471
# Epoch 13 - Avg Loss per sequence: 1.2125
# Epoch 13, Validation Loss: 1.2394
# Epoch 14 - Avg Loss per sequence: 1.1831
# Epoch 14, Validation Loss: 1.1958
# Epoch 15 - Avg Loss per sequence: 1.1869
# Epoch 15, Validation Loss: 1.1533
# Epoch 16 - Avg Loss per sequence: 1.1221
# Epoch 16, Validation Loss: 1.1230
# Epoch 17 - Avg Loss per sequence: 0.9947
# Epoch 17, Validation Loss: 1.0877
# Epoch 18 - Avg Loss per sequence: 1.0187
# Epoch 18, Validation Loss: 1.0616
# Epoch 19 - Avg Loss per sequence: 0.9412
# Epoch 19, Validation Loss: 1.0432
# Epoch 20 - Avg Loss per sequence: 0.9002
# Epoch 20, Validation Loss: 1.0176
# Epoch 21 - Avg Loss per sequence: 0.9586
# Epoch 21, Validation Loss: 0.9947
# Epoch 22 - Avg Loss per sequence: 0.8658
# Epoch 22, Validation Loss: 0.9944
# Epoch 23 - Avg Loss per sequence: 0.8640
# Epoch 23, Validation Loss: 0.9948
# Epoch 24 - Avg Loss per sequence: 0.8573
# Epoch 24, Validation Loss: 0.9845
# Epoch 25 - Avg Loss per sequence: 0.8578
# Epoch 25, Validation Loss: 0.9759
# Epoch 26 - Avg Loss per sequence: 0.8252
# Epoch 26, Validation Loss: 0.9599
# Epoch 27 - Avg Loss per sequence: 0.8237
# Epoch 27, Validation Loss: 0.9557
# Epoch 28 - Avg Loss per sequence: 0.8726
# Epoch 28, Validation Loss: 0.9611
# Epoch 29 - Avg Loss per sequence: 0.8227
# Epoch 29, Validation Loss: 0.9633
# Epoch 30 - Avg Loss per sequence: 0.8038
# Epoch 30, Validation Loss: 0.9700
# Epoch 31 - Avg Loss per sequence: 0.8473
# Epoch 31, Validation Loss: 0.9802
# Epoch 32 - Avg Loss per sequence: 0.8199
# Epoch 32, Validation Loss: 0.9644
# Epoch 33 - Avg Loss per sequence: 0.8498
# Epoch 33, Validation Loss: 0.9589
# Epoch 34 - Avg Loss per sequence: 0.8690
# Epoch 34, Validation Loss: 0.9280
# Epoch 35 - Avg Loss per sequence: 0.7943
# Epoch 35, Validation Loss: 0.9146
# Epoch 36 - Avg Loss per sequence: 0.7632
# Epoch 36, Validation Loss: 0.9057
# Epoch 37 - Avg Loss per sequence: 0.7757
# Epoch 37, Validation Loss: 0.9138
# Epoch 38 - Avg Loss per sequence: 0.6849
# Epoch 38, Validation Loss: 0.9102
# Epoch 39 - Avg Loss per sequence: 0.7586
# Epoch 39, Validation Loss: 0.9060
# Epoch 40 - Avg Loss per sequence: 0.8164
# Epoch 40, Validation Loss: 0.9001
# Epoch 41 - Avg Loss per sequence: 0.7661
# Epoch 41, Validation Loss: 0.9063
# Epoch 42 - Avg Loss per sequence: 0.8355
# Epoch 42, Validation Loss: 0.9037
# Epoch 43 - Avg Loss per sequence: 0.7428
# Epoch 43, Validation Loss: 0.8866
# Epoch 44 - Avg Loss per sequence: 0.7465
# Epoch 44, Validation Loss: 0.8809
# Epoch 45 - Avg Loss per sequence: 0.7806
# Epoch 45, Validation Loss: 0.8942
# Epoch 46 - Avg Loss per sequence: 0.6987
# Epoch 46, Validation Loss: 0.9132
# Epoch 47 - Avg Loss per sequence: 0.7110
# Epoch 47, Validation Loss: 0.9174
# Epoch 48 - Avg Loss per sequence: 0.7578
# Epoch 48, Validation Loss: 0.9012
# Epoch 49 - Avg Loss per sequence: 0.7137
# Epoch 49, Validation Loss: 0.9016
# Epoch 50 - Avg Loss per sequence: 0.7428
# Epoch 50, Validation Loss: 0.9158
# Epoch 51 - Avg Loss per sequence: 0.7917
# Epoch 51, Validation Loss: 0.9068
# Epoch 52 - Avg Loss per sequence: 0.7787
# Epoch 52, Validation Loss: 0.8987
# Epoch 53 - Avg Loss per sequence: 0.7461
# Epoch 53, Validation Loss: 0.8936
# Epoch 54 - Avg Loss per sequence: 0.7213
# Epoch 54, Validation Loss: 0.8808
# Epoch 55 - Avg Loss per sequence: 0.6868
# Epoch 55, Validation Loss: 0.8737
# Epoch 56 - Avg Loss per sequence: 0.6967
# Epoch 56, Validation Loss: 0.8746
# Epoch 57 - Avg Loss per sequence: 0.7118
# Epoch 57, Validation Loss: 0.8772
# Epoch 58 - Avg Loss per sequence: 0.7148
# Epoch 58, Validation Loss: 0.8917
# Epoch 59 - Avg Loss per sequence: 0.7221
# Epoch 59, Validation Loss: 0.8973
# Epoch 60 - Avg Loss per sequence: 0.7137
# Epoch 60, Validation Loss: 0.9055
# Epoch 61 - Avg Loss per sequence: 0.7191
# Epoch 61, Validation Loss: 0.8854
# Epoch 62 - Avg Loss per sequence: 0.6704
# Epoch 62, Validation Loss: 0.8859
# Epoch 63 - Avg Loss per sequence: 0.7134
# Epoch 63, Validation Loss: 0.9024
# Epoch 64 - Avg Loss per sequence: 0.6870
# Epoch 64, Validation Loss: 0.9073
# Epoch 65 - Avg Loss per sequence: 0.7537
# Epoch 65, Validation Loss: 0.9208
# Epoch 66 - Avg Loss per sequence: 0.6758
# Epoch 66, Validation Loss: 0.9116
# Epoch 67 - Avg Loss per sequence: 0.6621
# Epoch 67, Validation Loss: 0.9019
# Epoch 68 - Avg Loss per sequence: 0.7467
# Epoch 68, Validation Loss: 0.9050
# Epoch 69 - Avg Loss per sequence: 0.6786
# Epoch 69, Validation Loss: 0.9106
# Epoch 70 - Avg Loss per sequence: 0.7033
# Epoch 70, Validation Loss: 0.8988
# Epoch 71 - Avg Loss per sequence: 0.6776
# Epoch 71, Validation Loss: 0.8966
# Epoch 72 - Avg Loss per sequence: 0.7030
# Epoch 72, Validation Loss: 0.9179
# Epoch 73 - Avg Loss per sequence: 0.6675
# Epoch 73, Validation Loss: 0.9120
# Epoch 74 - Avg Loss per sequence: 0.6769
# Epoch 74, Validation Loss: 0.9309
# Epoch 75 - Avg Loss per sequence: 0.6866
# Epoch 75, Validation Loss: 0.9404
# Epoch 76 - Avg Loss per sequence: 0.6310
# Epoch 76, Validation Loss: 0.9103
# Epoch 77 - Avg Loss per sequence: 0.6666
# Epoch 77, Validation Loss: 0.9107
# Epoch 78 - Avg Loss per sequence: 0.6267
# Epoch 78, Validation Loss: 0.9153
# Epoch 79 - Avg Loss per sequence: 0.6686
# Epoch 79, Validation Loss: 0.9237
# Epoch 80 - Avg Loss per sequence: 0.6755
# Epoch 80, Validation Loss: 0.9207
# Epoch 81 - Avg Loss per sequence: 0.7050
# Epoch 81, Validation Loss: 0.8935
# Epoch 82 - Avg Loss per sequence: 0.6366
# Epoch 82, Validation Loss: 0.9242
# Epoch 83 - Avg Loss per sequence: 0.7067
# Epoch 83, Validation Loss: 0.9211
# Epoch 84 - Avg Loss per sequence: 0.6225
# Epoch 84, Validation Loss: 0.9571
# Epoch 85 - Avg Loss per sequence: 0.6579
# Epoch 85, Validation Loss: 0.9292
# Epoch 86 - Avg Loss per sequence: 0.6868
# Epoch 86, Validation Loss: 0.9185
# Epoch 87 - Avg Loss per sequence: 0.6458
# Epoch 87, Validation Loss: 0.9426
# Epoch 88 - Avg Loss per sequence: 0.5639
# Epoch 88, Validation Loss: 0.9343
# Epoch 89 - Avg Loss per sequence: 0.6189
# Epoch 89, Validation Loss: 0.9411
# Epoch 90 - Avg Loss per sequence: 0.6418
# Epoch 90, Validation Loss: 0.9440
# Epoch 91 - Avg Loss per sequence: 0.6321
# Epoch 91, Validation Loss: 0.9594
# Epoch 92 - Avg Loss per sequence: 0.6410
# Epoch 92, Validation Loss: 0.9528
# Epoch 93 - Avg Loss per sequence: 0.6181
# Epoch 93, Validation Loss: 0.9262
# Epoch 94 - Avg Loss per sequence: 0.6111
# Epoch 94, Validation Loss: 0.9248
# Epoch 95 - Avg Loss per sequence: 0.6175
# Epoch 95, Validation Loss: 0.9285
# Epoch 96 - Avg Loss per sequence: 0.6167
# Epoch 96, Validation Loss: 0.9425
# Epoch 97 - Avg Loss per sequence: 0.6202
# Epoch 97, Validation Loss: 0.9561
# Epoch 98 - Avg Loss per sequence: 0.6630
# Epoch 98, Validation Loss: 0.9670
# Epoch 99 - Avg Loss per sequence: 0.5790
# Epoch 99, Validation Loss: 0.9654
# Epoch 100 - Avg Loss per sequence: 0.6114
# Epoch 100, Validation Loss: 0.9829
# Epoch 101 - Avg Loss per sequence: 0.6169
# Epoch 101, Validation Loss: 0.9669
# Epoch 102 - Avg Loss per sequence: 0.5812
# Epoch 102, Validation Loss: 0.9677
# Epoch 103 - Avg Loss per sequence: 0.6378
# Epoch 103, Validation Loss: 0.9548
# Epoch 104 - Avg Loss per sequence: 0.6263
# Epoch 104, Validation Loss: 0.9427
# Epoch 105 - Avg Loss per sequence: 0.6070
# Epoch 105, Validation Loss: 0.9322
# Epoch 106 - Avg Loss per sequence: 0.5897
# Epoch 106, Validation Loss: 0.9404
# Epoch 107 - Avg Loss per sequence: 0.6017
# Epoch 107, Validation Loss: 0.9631
# Epoch 108 - Avg Loss per sequence: 0.6707
# Epoch 108, Validation Loss: 0.9818
# Epoch 109 - Avg Loss per sequence: 0.6095
# Epoch 109, Validation Loss: 0.9794
# Epoch 110 - Avg Loss per sequence: 0.5938
# Epoch 110, Validation Loss: 0.9832
# Epoch 111 - Avg Loss per sequence: 0.6264
# Epoch 111, Validation Loss: 1.0222
# Epoch 112 - Avg Loss per sequence: 0.6409
# Epoch 112, Validation Loss: 1.0170
# Epoch 113 - Avg Loss per sequence: 0.6055
# Epoch 113, Validation Loss: 0.9956
# Epoch 114 - Avg Loss per sequence: 0.5664
# Epoch 114, Validation Loss: 0.9869
# Epoch 115 - Avg Loss per sequence: 0.5708
# Epoch 115, Validation Loss: 1.0145
# Epoch 116 - Avg Loss per sequence: 0.5674
# Epoch 116, Validation Loss: 1.0483
# Epoch 117 - Avg Loss per sequence: 0.6301
# Epoch 117, Validation Loss: 1.0363
# Epoch 118 - Avg Loss per sequence: 0.5890
# Epoch 118, Validation Loss: 1.0274
# Epoch 119 - Avg Loss per sequence: 0.6438
# Epoch 119, Validation Loss: 1.0254
# Epoch 120 - Avg Loss per sequence: 0.5855
# Epoch 120, Validation Loss: 1.0326
# Epoch 121 - Avg Loss per sequence: 0.5672
# Epoch 121, Validation Loss: 1.0274
# Epoch 122 - Avg Loss per sequence: 0.5616
# Epoch 122, Validation Loss: 1.0743
# Epoch 123 - Avg Loss per sequence: 0.6395
# Epoch 123, Validation Loss: 1.0319
# Epoch 124 - Avg Loss per sequence: 0.5496
# Epoch 124, Validation Loss: 1.0264
# Epoch 125 - Avg Loss per sequence: 0.5657
# Epoch 125, Validation Loss: 1.0345
# Epoch 126 - Avg Loss per sequence: 0.6040
# Epoch 126, Validation Loss: 1.0411
# Epoch 127 - Avg Loss per sequence: 0.5451
# Epoch 127, Validation Loss: 1.0393
# Epoch 128 - Avg Loss per sequence: 0.5900
# Epoch 128, Validation Loss: 1.0183
# Epoch 129 - Avg Loss per sequence: 0.5516
# Epoch 129, Validation Loss: 1.0114
# Epoch 130 - Avg Loss per sequence: 0.5977
# Epoch 130, Validation Loss: 1.0356
# Epoch 131 - Avg Loss per sequence: 0.6187
# Epoch 131, Validation Loss: 1.0547
# Epoch 132 - Avg Loss per sequence: 0.5809
# Epoch 132, Validation Loss: 1.0685
# Epoch 133 - Avg Loss per sequence: 0.6150
# Epoch 133, Validation Loss: 1.0307
# Epoch 134 - Avg Loss per sequence: 0.5778
# Epoch 134, Validation Loss: 1.0294
# Epoch 135 - Avg Loss per sequence: 0.5322
# Epoch 135, Validation Loss: 1.0470
# Epoch 136 - Avg Loss per sequence: 0.5211
# Epoch 136, Validation Loss: 1.0330
# Epoch 137 - Avg Loss per sequence: 0.5541
# Epoch 137, Validation Loss: 1.0536
# Epoch 138 - Avg Loss per sequence: 0.5624
# Epoch 138, Validation Loss: 1.0409
# Epoch 139 - Avg Loss per sequence: 0.5634
# Epoch 139, Validation Loss: 1.0390
# Epoch 140 - Avg Loss per sequence: 0.5799
# Epoch 140, Validation Loss: 1.0592
# Epoch 141 - Avg Loss per sequence: 0.6049
# Epoch 141, Validation Loss: 1.0716
# Epoch 142 - Avg Loss per sequence: 0.5978
# Epoch 142, Validation Loss: 1.0968
# Epoch 143 - Avg Loss per sequence: 0.5490
# Epoch 143, Validation Loss: 1.0827
# Epoch 144 - Avg Loss per sequence: 0.5521
# Epoch 144, Validation Loss: 1.0347
# Epoch 145 - Avg Loss per sequence: 0.5797
# Epoch 145, Validation Loss: 1.0197
# Epoch 146 - Avg Loss per sequence: 0.5534
# Epoch 146, Validation Loss: 1.0223
# Epoch 147 - Avg Loss per sequence: 0.5572
# Epoch 147, Validation Loss: 1.0507
# Epoch 148 - Avg Loss per sequence: 0.5391
# Epoch 148, Validation Loss: 1.0542
# Epoch 149 - Avg Loss per sequence: 0.5223
# Epoch 149, Validation Loss: 1.0696
# Epoch 150 - Avg Loss per sequence: 0.5501
# Epoch 150, Validation Loss: 1.0609
# Epoch 151 - Avg Loss per sequence: 0.5805
# Epoch 151, Validation Loss: 1.0515
# Epoch 152 - Avg Loss per sequence: 0.5623
# Epoch 152, Validation Loss: 1.0844
# Epoch 153 - Avg Loss per sequence: 0.5367
# Epoch 153, Validation Loss: 1.0910
# Epoch 154 - Avg Loss per sequence: 0.5143
# Epoch 154, Validation Loss: 1.0847
# Epoch 155 - Avg Loss per sequence: 0.5013
# Epoch 155, Validation Loss: 1.0796
# Epoch 156 - Avg Loss per sequence: 0.5485
# Epoch 156, Validation Loss: 1.0799
# Epoch 157 - Avg Loss per sequence: 0.5654
# Epoch 157, Validation Loss: 1.1150
# Epoch 158 - Avg Loss per sequence: 0.4964
# Epoch 158, Validation Loss: 1.1154
# Epoch 159 - Avg Loss per sequence: 0.5681
# Epoch 159, Validation Loss: 1.0662
# Epoch 160 - Avg Loss per sequence: 0.5095
# Epoch 160, Validation Loss: 1.0926
# Epoch 161 - Avg Loss per sequence: 0.5360
# Epoch 161, Validation Loss: 1.0467
# Epoch 162 - Avg Loss per sequence: 0.5089
# Epoch 162, Validation Loss: 1.0532
# Epoch 163 - Avg Loss per sequence: 0.5054
# Epoch 163, Validation Loss: 1.0509
# Epoch 164 - Avg Loss per sequence: 0.5787
# Epoch 164, Validation Loss: 1.0502
# Epoch 165 - Avg Loss per sequence: 0.4640
# Epoch 165, Validation Loss: 1.0630
# Epoch 166 - Avg Loss per sequence: 0.5068
# Epoch 166, Validation Loss: 1.0542
# Epoch 167 - Avg Loss per sequence: 0.5457
# Epoch 167, Validation Loss: 1.0798
# Epoch 168 - Avg Loss per sequence: 0.5448
# Epoch 168, Validation Loss: 1.0653
# Epoch 169 - Avg Loss per sequence: 0.5189
# Epoch 169, Validation Loss: 1.1032
# Epoch 170 - Avg Loss per sequence: 0.5108
# Epoch 170, Validation Loss: 1.1149
# Epoch 171 - Avg Loss per sequence: 0.5709
# Epoch 171, Validation Loss: 1.0978
# Epoch 172 - Avg Loss per sequence: 0.5150
# Epoch 172, Validation Loss: 1.1012
# Epoch 173 - Avg Loss per sequence: 0.5496
# Epoch 173, Validation Loss: 1.1011
# Epoch 174 - Avg Loss per sequence: 0.5685
# Epoch 174, Validation Loss: 1.1114
# Epoch 175 - Avg Loss per sequence: 0.5612
# Epoch 175, Validation Loss: 1.0852
# Epoch 176 - Avg Loss per sequence: 0.5171
# Epoch 176, Validation Loss: 1.1144
# Epoch 177 - Avg Loss per sequence: 0.5062
# Epoch 177, Validation Loss: 1.0962
# Epoch 178 - Avg Loss per sequence: 0.5416
# Epoch 178, Validation Loss: 1.1301
# Epoch 179 - Avg Loss per sequence: 0.4972
# Epoch 179, Validation Loss: 1.1518
# Epoch 180 - Avg Loss per sequence: 0.5092
# Epoch 180, Validation Loss: 1.1609
# Epoch 181 - Avg Loss per sequence: 0.5451
# Epoch 181, Validation Loss: 1.1257
# Epoch 182 - Avg Loss per sequence: 0.4975
# Epoch 182, Validation Loss: 1.1035
# Epoch 183 - Avg Loss per sequence: 0.5028
# Epoch 183, Validation Loss: 1.1239
# Epoch 184 - Avg Loss per sequence: 0.5038
# Epoch 184, Validation Loss: 1.2178
# Epoch 185 - Avg Loss per sequence: 0.4605
# Epoch 185, Validation Loss: 1.1551
# Epoch 186 - Avg Loss per sequence: 0.5177
# Epoch 186, Validation Loss: 1.1265
# Epoch 187 - Avg Loss per sequence: 0.5846
# Epoch 187, Validation Loss: 1.1375
# Epoch 188 - Avg Loss per sequence: 0.5185
# Epoch 188, Validation Loss: 1.1720
# Epoch 189 - Avg Loss per sequence: 0.5137
# Epoch 189, Validation Loss: 1.1798
# Epoch 190 - Avg Loss per sequence: 0.5345
# Epoch 190, Validation Loss: 1.1624
# Epoch 191 - Avg Loss per sequence: 0.5088
# Epoch 191, Validation Loss: 1.1712
# Epoch 192 - Avg Loss per sequence: 0.5150
# Epoch 192, Validation Loss: 1.1040
# Epoch 193 - Avg Loss per sequence: 0.5105
# Epoch 193, Validation Loss: 1.0937
# Epoch 194 - Avg Loss per sequence: 0.4651
# Epoch 194, Validation Loss: 1.1117
# Epoch 195 - Avg Loss per sequence: 0.4551
# Epoch 195, Validation Loss: 1.0986
# Epoch 196 - Avg Loss per sequence: 0.4876
# Epoch 196, Validation Loss: 1.1164
# Epoch 197 - Avg Loss per sequence: 0.5171
# Epoch 197, Validation Loss: 1.1432
# Epoch 198 - Avg Loss per sequence: 0.4802
# Epoch 198, Validation Loss: 1.1368
# Epoch 199 - Avg Loss per sequence: 0.4874
# Epoch 199, Validation Loss: 1.1497
# Epoch 200 - Avg Loss per sequence: 0.4866
# Epoch 200, Validation Loss: 1.1269
# Epoch 201 - Avg Loss per sequence: 0.4501
# Epoch 201, Validation Loss: 1.1341
# Epoch 202 - Avg Loss per sequence: 0.4908
# Epoch 202, Validation Loss: 1.1302
# Epoch 203 - Avg Loss per sequence: 0.4468
# Epoch 203, Validation Loss: 1.1249
# Epoch 204 - Avg Loss per sequence: 0.4713
# Epoch 204, Validation Loss: 1.1436
# Epoch 205 - Avg Loss per sequence: 0.5147
# Epoch 205, Validation Loss: 1.1709
# Epoch 206 - Avg Loss per sequence: 0.5182
# Epoch 206, Validation Loss: 1.1421
# Epoch 207 - Avg Loss per sequence: 0.4521
# Epoch 207, Validation Loss: 1.1373
# Epoch 208 - Avg Loss per sequence: 0.5018
# Epoch 208, Validation Loss: 1.1492
# Epoch 209 - Avg Loss per sequence: 0.5105
# Epoch 209, Validation Loss: 1.1859
# Epoch 210 - Avg Loss per sequence: 0.4915
# Epoch 210, Validation Loss: 1.1633
# Epoch 211 - Avg Loss per sequence: 0.4724
# Epoch 211, Validation Loss: 1.1288
# Epoch 212 - Avg Loss per sequence: 0.5035
# Epoch 212, Validation Loss: 1.1268
# Epoch 213 - Avg Loss per sequence: 0.4850
# Epoch 213, Validation Loss: 1.1654
# Epoch 214 - Avg Loss per sequence: 0.4247
# Epoch 214, Validation Loss: 1.1730
# Epoch 215 - Avg Loss per sequence: 0.4807
# Epoch 215, Validation Loss: 1.1722
# Epoch 216 - Avg Loss per sequence: 0.5401
# Epoch 216, Validation Loss: 1.1580
# Epoch 217 - Avg Loss per sequence: 0.4708
# Epoch 217, Validation Loss: 1.1781
# Epoch 218 - Avg Loss per sequence: 0.4828
# Epoch 218, Validation Loss: 1.1325
# Epoch 219 - Avg Loss per sequence: 0.4924
# Epoch 219, Validation Loss: 1.1402
# Epoch 220 - Avg Loss per sequence: 0.4431
# Epoch 220, Validation Loss: 1.1478
# Epoch 221 - Avg Loss per sequence: 0.4633
# Epoch 221, Validation Loss: 1.1524
# Epoch 222 - Avg Loss per sequence: 0.4667
# Epoch 222, Validation Loss: 1.1560
# Epoch 223 - Avg Loss per sequence: 0.4857
# Epoch 223, Validation Loss: 1.1769
# Epoch 224 - Avg Loss per sequence: 0.4646
# Epoch 224, Validation Loss: 1.1850
# Epoch 225 - Avg Loss per sequence: 0.4658
# Epoch 225, Validation Loss: 1.1757
# Epoch 226 - Avg Loss per sequence: 0.4546
# Epoch 226, Validation Loss: 1.1751
# Epoch 227 - Avg Loss per sequence: 0.5012
# Epoch 227, Validation Loss: 1.1733
# Epoch 228 - Avg Loss per sequence: 0.4015
# Epoch 228, Validation Loss: 1.1477
# Epoch 229 - Avg Loss per sequence: 0.5381
# Epoch 229, Validation Loss: 1.1573
# Epoch 230 - Avg Loss per sequence: 0.4221
# Epoch 230, Validation Loss: 1.1933
# Epoch 231 - Avg Loss per sequence: 0.4537
# Epoch 231, Validation Loss: 1.2101
# Epoch 232 - Avg Loss per sequence: 0.4898
# Epoch 232, Validation Loss: 1.2317
# Epoch 233 - Avg Loss per sequence: 0.4735
# Epoch 233, Validation Loss: 1.2376
# Epoch 234 - Avg Loss per sequence: 0.4529
# Epoch 234, Validation Loss: 1.2476
# Epoch 235 - Avg Loss per sequence: 0.4576
# Epoch 235, Validation Loss: 1.2328
# Epoch 236 - Avg Loss per sequence: 0.4968
# Epoch 236, Validation Loss: 1.2251
# Epoch 237 - Avg Loss per sequence: 0.4743
# Epoch 237, Validation Loss: 1.2071
# Epoch 238 - Avg Loss per sequence: 0.4769
# Epoch 238, Validation Loss: 1.2451
# Epoch 239 - Avg Loss per sequence: 0.4214
# Epoch 239, Validation Loss: 1.2631
# Epoch 240 - Avg Loss per sequence: 0.4470
# Epoch 240, Validation Loss: 1.2460
# Epoch 241 - Avg Loss per sequence: 0.4597
# Epoch 241, Validation Loss: 1.2198
# Epoch 242 - Avg Loss per sequence: 0.4214
# Epoch 242, Validation Loss: 1.2314
# Epoch 243 - Avg Loss per sequence: 0.4633
# Epoch 243, Validation Loss: 1.2184
# Epoch 244 - Avg Loss per sequence: 0.4515
# Epoch 244, Validation Loss: 1.2346
# Epoch 245 - Avg Loss per sequence: 0.4015
# Epoch 245, Validation Loss: 1.2133
# Epoch 246 - Avg Loss per sequence: 0.4302
# Epoch 246, Validation Loss: 1.2212
# Epoch 247 - Avg Loss per sequence: 0.4380
# Epoch 247, Validation Loss: 1.2492
# Epoch 248 - Avg Loss per sequence: 0.4788
# Epoch 248, Validation Loss: 1.2746
# Epoch 249 - Avg Loss per sequence: 0.4896
# Epoch 249, Validation Loss: 1.2175
# Epoch 250 - Avg Loss per sequence: 0.4463
# Epoch 250, Validation Loss: 1.1986
# Epoch 251 - Avg Loss per sequence: 0.4687
# Epoch 251, Validation Loss: 1.2051
# Epoch 252 - Avg Loss per sequence: 0.3830
# Epoch 252, Validation Loss: 1.1953
# Epoch 253 - Avg Loss per sequence: 0.4632
# Epoch 253, Validation Loss: 1.1761
# Epoch 254 - Avg Loss per sequence: 0.4232
# Epoch 254, Validation Loss: 1.2008
# Epoch 255 - Avg Loss per sequence: 0.4989
# Epoch 255, Validation Loss: 1.2171
# Epoch 256 - Avg Loss per sequence: 0.4484
# Epoch 256, Validation Loss: 1.2009
# Epoch 257 - Avg Loss per sequence: 0.4096
# Epoch 257, Validation Loss: 1.2117
# Epoch 258 - Avg Loss per sequence: 0.4106
# Epoch 258, Validation Loss: 1.2133
# Epoch 259 - Avg Loss per sequence: 0.4199
# Epoch 259, Validation Loss: 1.2171
# Epoch 260 - Avg Loss per sequence: 0.4169
# Epoch 260, Validation Loss: 1.2275
# Epoch 261 - Avg Loss per sequence: 0.4486
# Epoch 261, Validation Loss: 1.2406
# Epoch 262 - Avg Loss per sequence: 0.3806
# Epoch 262, Validation Loss: 1.2434
# Epoch 263 - Avg Loss per sequence: 0.4717
# Epoch 263, Validation Loss: 1.2925
# Epoch 264 - Avg Loss per sequence: 0.4212
# Epoch 264, Validation Loss: 1.2913
# Epoch 265 - Avg Loss per sequence: 0.4674
# Epoch 265, Validation Loss: 1.2572
# Epoch 266 - Avg Loss per sequence: 0.4060
# Epoch 266, Validation Loss: 1.2294
# Epoch 267 - Avg Loss per sequence: 0.4780
# Epoch 267, Validation Loss: 1.2706
# Epoch 268 - Avg Loss per sequence: 0.4826
# Epoch 268, Validation Loss: 1.2860
# Epoch 269 - Avg Loss per sequence: 0.4200
# Epoch 269, Validation Loss: 1.2756
# Epoch 270 - Avg Loss per sequence: 0.4691
# Epoch 270, Validation Loss: 1.2574
# Epoch 271 - Avg Loss per sequence: 0.3887
# Epoch 271, Validation Loss: 1.2654
# Epoch 272 - Avg Loss per sequence: 0.4143
# Epoch 272, Validation Loss: 1.2799
# Epoch 273 - Avg Loss per sequence: 0.4022
# Epoch 273, Validation Loss: 1.2853
# Epoch 274 - Avg Loss per sequence: 0.4323
# Epoch 274, Validation Loss: 1.2982
# Epoch 275 - Avg Loss per sequence: 0.4310
# Epoch 275, Validation Loss: 1.3081
# Epoch 276 - Avg Loss per sequence: 0.4062
# Epoch 276, Validation Loss: 1.2897
# Epoch 277 - Avg Loss per sequence: 0.4014
# Epoch 277, Validation Loss: 1.2573
# Epoch 278 - Avg Loss per sequence: 0.3879
# Epoch 278, Validation Loss: 1.2505
# Epoch 279 - Avg Loss per sequence: 0.3719
# Epoch 279, Validation Loss: 1.2653
# Epoch 280 - Avg Loss per sequence: 0.4257
# Epoch 280, Validation Loss: 1.2821
# Epoch 281 - Avg Loss per sequence: 0.4067
# Epoch 281, Validation Loss: 1.3218
# Epoch 282 - Avg Loss per sequence: 0.4283
# Epoch 282, Validation Loss: 1.3247
# Epoch 283 - Avg Loss per sequence: 0.4250
# Epoch 283, Validation Loss: 1.3160
# Epoch 284 - Avg Loss per sequence: 0.4079
# Epoch 284, Validation Loss: 1.3200
# Epoch 285 - Avg Loss per sequence: 0.4266
# Epoch 285, Validation Loss: 1.3359
# Epoch 286 - Avg Loss per sequence: 0.4280
# Epoch 286, Validation Loss: 1.3250
# Epoch 287 - Avg Loss per sequence: 0.4232
# Epoch 287, Validation Loss: 1.3086
# Epoch 288 - Avg Loss per sequence: 0.3603
# Epoch 288, Validation Loss: 1.3243
# Epoch 289 - Avg Loss per sequence: 0.3830
# Epoch 289, Validation Loss: 1.3269
# Epoch 290 - Avg Loss per sequence: 0.3871
# Epoch 290, Validation Loss: 1.3014
# Epoch 291 - Avg Loss per sequence: 0.3916
# Epoch 291, Validation Loss: 1.3214
# Epoch 292 - Avg Loss per sequence: 0.3656
# Epoch 292, Validation Loss: 1.3391
# Epoch 293 - Avg Loss per sequence: 0.3548
# Epoch 293, Validation Loss: 1.3273
# Epoch 294 - Avg Loss per sequence: 0.3689
# Epoch 294, Validation Loss: 1.3396
# Epoch 295 - Avg Loss per sequence: 0.3899
# Epoch 295, Validation Loss: 1.3578
# Epoch 296 - Avg Loss per sequence: 0.3770
# Epoch 296, Validation Loss: 1.3481
# Epoch 297 - Avg Loss per sequence: 0.4771
# Epoch 297, Validation Loss: 1.3378
# Epoch 298 - Avg Loss per sequence: 0.3981
# Epoch 298, Validation Loss: 1.3682
# Epoch 299 - Avg Loss per sequence: 0.3822
# Epoch 299, Validation Loss: 1.3829

# %%
plt.figure(figsize=(6,4))
plt.plot(range(1, len(train_losses)+1), train_losses, label='Training Loss', color='blue')
plt.plot(range(1, len(validation_losses)+1), validation_losses, label = 'Validation Loss', color='orange')
plt.title('Train vs. Validation Loss')
plt.xlabel('Episodes')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# EVALUATION AND TESTING
#
# Validation Data

# %%
eval_model = LSTMModel(vocab_size=num_bins, embedding_dim=32, hidden_dim=64, output_dim=num_bins)
eval_model.load_state_dict(torch.load('best_model.pth', weights_only=False))

## VALIDATION
model.eval()
val_loss = []
val_perplexity = []

# No weight updates
with torch.no_grad():
    
    for sequence in val_data:
        
        sequence_input = torch.tensor(sequence[:-1]).unsqueeze(0)   # Exclude last token
        targets = torch.tensor(sequence[1:]).unsqueeze(0)           # Exclude first token
        logits, _ = eval_model(sequence_input)  # Forward pass
        logits = logits.view(-1, logits.size(-1))  # Shape: [49, 30]
        targets = targets.view(-1)  # Shape: [49] 
        
        # Cross entropy Loss
        loss = criterion(logits, targets)
        val_loss.append(loss.item())

        # Log probabilities
        log_probs = F.log_softmax(logits, dim=-1)
        target_log_probs = log_probs[range(len(targets)), targets]

        # Perplexity: exp(-average log probability)
        avg_log_prob = target_log_probs.mean()
        perplexity = torch.exp(-avg_log_prob).item()
        val_perplexity.append(perplexity)

# %% [markdown]
# Test Data with Teacher forcing

# %%
start_test_idx = np.random.choice(range(len(test_data_temp)-seq_len), size=100, replace=True)
test_data = prep_data(seq_len=seq_len, start_indexes=start_test_idx, data=test_data_temp)

# %%
test_model = LSTMModel(vocab_size=num_bins, embedding_dim=32, hidden_dim=64, output_dim=num_bins)
test_model.load_state_dict(torch.load('best_model.pth', weights_only=False))

## TEST DATA
test_model.eval()
test_loss = []
test_perplexity = []

# No weight updates
with torch.no_grad():
    
    for sequence in test_data:
        
        sequence_input = torch.tensor(sequence[:-1]).unsqueeze(0)   # Exclude last token
        targets = torch.tensor(sequence[1:]).unsqueeze(0)           # Exclude first token
        logits, _ = test_model(sequence_input)  # Forward pass
        logits = logits.view(-1, logits.size(-1))  # Shape: [49, 30]
        targets = targets.view(-1)  # Shape: [49] 
        
        # Cross entropy Loss
        loss = criterion(logits, targets)
        test_loss.append(loss.item())

        # Log probabilities
        log_probs = F.log_softmax(logits, dim=-1)
        target_log_probs = log_probs[range(len(targets)), targets]

        # Perplexity: exp(-average log probability)
        avg_log_prob = target_log_probs.mean()
        perplexity = torch.exp(-avg_log_prob).item()
        test_perplexity.append(perplexity)

# %% [markdown]
# #### Perplexity Score
#
# $\text{PP}_N(x) = \frac{1}{\left(\prod_{i=1}^{N} P(x_i \mid w_1 \cdots x_{i-1})\right)^{\frac{1}{N}}} = \left(\prod_{i=1}^{N} P(x_i \mid x_1 \cdots x_{i-1})\right)^{-\frac{1}{N}} = e^{-\frac{1}{N} \sum_{i=1}^{N} \log P(x_i \mid x_{1:i-1})} $
#
#
# $\text{PP}_N(x) = \exp\left(-\frac{1}{N} \sum_{i=1}^{N} \log P(x_i \mid x_{1:i-1})\right)$

# %%
val_perplexity = np.array(val_perplexity)
test_perplexity = np.array(test_perplexity)

mean_test = np.mean(test_perplexity)
mean_val = np.mean(val_perplexity)

fig, axs = plt.subplots(1, 2, figsize=(10, 3))

# Plot 1: Validation & Test Loss
axs[0].plot(val_loss, label='Validation Loss', color='orange')
axs[0].plot(test_loss, label='Test Loss', color='darkblue')
axs[0].legend()
axs[0].set_title('Validation & Test Loss for the Best Model (Teacher Forcing)', size=10)
axs[0].set_xlabel('# of Sequences')
axs[0].set_ylabel('Loss')
axs[0].set_ylim(0, 2)

# Plot 2: Histogram of Perplexity Distribution
axs[1].hist(val_perplexity, color='orange', bins=10, alpha=0.7, label='Validation Perplexity')
axs[1].hist(test_perplexity, color='darkblue', bins=10, alpha=0.7, label='Test Perplexity')
axs[1].set_title('Validation & Test Data: Perplexity Distribution', size=10)
axs[1].set_xlabel('Sequence Perplexity')
axs[1].set_ylabel('Frequency')
axs[1].set_xlim(0, 5)

# Vertical lines for the mean values on the histogram
axs[1].axvline(mean_val, color='red', linewidth=1, linestyle='dashed')
axs[1].axvline(mean_test, color='red', linewidth=1, linestyle='dashed')
axs[1].text(mean_val-2.0, axs[1].get_ylim()[1] * 0.9, f'Mean Validation: {mean_val:.2f}', color='red')
axs[1].text(mean_test+0.1, axs[1].get_ylim()[1] * 0.9, f'Mean Test: {mean_test:.2f}', color='red')

plt.tight_layout()
plt.show()

# %% [markdown]
# Inference on Test data

# %%
## TESTING
test_losses = []
trajectories = []

for sequence in test_data:
    init_real_token = sequence[0]
    sim_trajectory = [init_real_token]
    model.eval()
    # Initialize hidden and cell states to zero
    ## PLEASE ADJUST WHEN HAVING MULTIPLE LSTM LAYERS
    h_n = torch.zeros(1, 1, 64)
    c_n = torch.zeros(1, 1, 64)
    ##
    with torch.no_grad():
        token_loss = 0
        for i in range(1, len(sequence)):
            # Last value in the trajectory
            sequence_input = torch.tensor([sim_trajectory[-1]]).unsqueeze(0)
            
            # Get the model's prediction and pass the hidden and cell states
            logits, (h_n, c_n) = model(sequence_input, (h_n, c_n))
            
            # Apply softmax to get probabilities
            probs = torch.softmax(logits, dim=-1)
            probs = probs.squeeze()
            predicted_token = torch.multinomial(probs, num_samples=1).item()
            sim_trajectory.append(predicted_token)
            
            # Loss calculation
            true_token = torch.tensor([sequence[i]]).unsqueeze(0)
            true_token = true_token.view(-1)  
            logits = logits.view(-1, logits.size(-1))                                             
            loss = criterion(logits, true_token)
            token_loss += loss.item()
            
    test_losses.append(token_loss/len(sequence))
    trajectories.append(sim_trajectory)

# %%
fig, axes = plt.subplots(2, 3, figsize=(15, 6))  # 2 rows, 3 columns, and adjust the size
axes = axes.flatten()
for i in range(6):
    axes[i].plot(test_data[i], label='Real Trajectory', color = 'lime')
    axes[i].plot(trajectories[i], label='Simulated Trajectory', color = 'crimson')
    axes[i].legend()
    axes[i].set_title(f'Trajectory {i+1}')
plt.tight_layout()
plt.show()

# %% [markdown]
# Testing with ARGMAX instead of Sampling

# %%
## TESTING
test_losses = []
trajectories_2 = []

for sequence in test_data:
    init_real_token = sequence[0]
    sim_trajectory = [init_real_token]
    model.eval()
    # Initialize hidden and cell states to zero
    ## PLEASE ADJUST WHEN HAVING MULTIPLE LSTM LAYERS
    h_n = torch.zeros(1, 1, 64)
    c_n = torch.zeros(1, 1, 64)
    ##
    with torch.no_grad():
        token_loss = 0
        for i in range(1, len(sequence)):
            # Last value in the trajectory
            sequence_input = torch.tensor([sim_trajectory[-1]]).unsqueeze(0)
            
            # Get the model's prediction and pass the hidden and cell states
            logits, (h_n, c_n) = model(sequence_input, (h_n, c_n))
            
            # Apply softmax to get probabilities
            probs = torch.softmax(logits, dim=-1)
            probs = probs.squeeze()
            predicted_token = torch.argmax(probs).item()
            sim_trajectory.append(predicted_token)
            
            # Loss calculation
            true_token = torch.tensor([sequence[i]]).unsqueeze(0)
            true_token = true_token.view(-1)  
            logits = logits.view(-1, logits.size(-1))                                             
            loss = criterion(logits, true_token)
            token_loss += loss.item()
            
    test_losses.append(token_loss/len(sequence))
    trajectories_2.append(sim_trajectory)

# %% [markdown]
# #### WHEN ARGMAX IS USED

# %%
fig, axes = plt.subplots(2, 3, figsize=(15, 6))  # 2 rows, 3 columns, and adjust the size
axes = axes.flatten()
for i in range(6):
    axes[i].plot(test_data[i], label='Real Trajectory', color = 'lime')
    axes[i].plot(trajectories_2[i], label='Simulated Trajectory', color = 'crimson')
    axes[i].legend()
    axes[i].set_title(f'Trajectory {i+1}')
plt.tight_layout()
plt.show()

# %% [markdown]
# Summary Statistics

# %%
test_fake_data=np.array(trajectories)

def calculate_statistics(trajectories):
    means = []
    variances = []
    std_devs = []
    skewness = []
    kurtos = []
    max_vals = []
    min_vals = []

    for traj in trajectories:
        means.append(np.mean(traj))
        variances.append(np.var(traj))
        std_devs.append(np.std(traj))
        skewness.append(skew(traj))
        kurtos.append(kurtosis(traj))
        max_vals.append(np.max(traj))
        min_vals.append(np.min(traj))
    
    return means, variances, std_devs, skewness, kurtos, max_vals, min_vals

# Statistics for real and simulated trajectories
real_means, real_variances, real_std_devs, real_skew, real_kurtosis, real_max_vals, real_min_vals = calculate_statistics(test_data)
sim_means, sim_variances, sim_std_devs, sim_skew, sim_kurtosis, sim_max_vals, sim_min_vals = calculate_statistics(test_fake_data)

# %%
fig, axs = plt.subplots(1, 3, figsize=(15, 3))

# Plot 1: Variance Distribution
axs[0].hist(sim_variances, bins=15, alpha=0.4, label='Simulated', color='red')
axs[0].hist(real_variances, bins=3, alpha=0.7, label='Real', color='green')
axs[0].legend(loc='upper right')
axs[0].set_title('Distribution of Variances')
axs[0].set_xlabel('Value')
axs[0].set_ylabel('Frequency')

# Plot 2: Skewness Distribution
axs[1].hist(sim_skew, bins=15, alpha=0.4, label='Simulated', color='red')
axs[1].hist(real_skew, bins=5, alpha=0.7, label='Real', color='green')
axs[1].legend(loc='upper right')
axs[1].set_title('Distribution of Skewness')
axs[1].set_xlabel('Value')
axs[1].set_ylabel('Frequency')

# Plot 3: Kurtosis Distribution
axs[2].hist(sim_kurtosis, bins=15, alpha=0.4, label='Simulated', color='red')
axs[2].hist(real_kurtosis, bins=3, alpha=0.7, label='Real', color='green')
axs[2].legend(loc='upper right')
axs[2].set_title('Distribution of Kurtosis')
axs[2].set_xlabel('Value')
axs[2].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# Autocorrelation
#
# $ACF(k) = Corr(x_t, x_{t-k})$

# %%
# Function to calculate ACF for each trajectory
def calculate_acf(trajectories, nlags=20):
    acfs = []
    for traj in trajectories:
        acf_values = acf(traj, fft=False, nlags=nlags)
        acfs.append(acf_values)
    return np.array(acfs)

# Function to calculate PACF for each trajectory
def calculate_pacf(trajectories, nlags=20):
    pacfs = []
    for traj in trajectories:
        pacf_values = pacf(traj, nlags=nlags)
        pacfs.append(pacf_values)
    return np.array(pacfs)

# ACFs for real and simulated trajectories
real_acfs = calculate_acf(test_data)
simulated_acfs = calculate_acf(test_fake_data)
# Average the ACFs across all trajectories
avg_real_acf = np.mean(real_acfs, axis=0)
avg_simulated_acf = np.mean(simulated_acfs, axis=0)

# Calculate PACFs for real and simulated trajectories
real_pacfs = calculate_pacf(test_data)
simulated_pacfs = calculate_pacf(test_fake_data)
# Average the PACFs across all trajectories
avg_real_pacf = np.mean(real_pacfs, axis=0)
avg_simulated_pacf = np.mean(simulated_pacfs, axis=0)

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 3))

# Plot the averaged ACFs
axs[0].plot(avg_real_acf, label='Real', color='green')
axs[0].plot(avg_simulated_acf, label='Simulated', color='red')
axs[0].set_title('Average Autocorrelation Function')
axs[0].set_xlabel('Lag')
axs[0].set_ylabel('Autocorrelation')
axs[0].legend()

# Plot the averaged PACFs
axs[1].plot(avg_real_pacf, label='Real', color='green')
axs[1].plot(avg_simulated_pacf, label='Simulated', color='red')
axs[1].set_title('Average Partial Autocorrelation Function')
axs[1].set_xlabel('Lag')
axs[1].set_ylabel('Partial Autocorrelation')
axs[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### GAN Framework

# %% [markdown]
# Generator & Discriminator Setup

# %%
## Change architecture when moving to refining your model
##

# Same as in self-supervised setting
class LSTMGenerator(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim):
        super(LSTMGenerator, self).__init__()
        # Embedding Layer
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        # LSTM Layer
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True)
        # Fully Connected Layer
        self.fc = nn.Linear(hidden_dim, output_dim)
    
    def forward(self, x, hidden=None):
        embedded = self.embedding(x)
        lstm_out, (h_n, c_n) = self.lstm(embedded, hidden)
        logits = self.fc(lstm_out)
        return logits, hidden

## Simple Discriminator LSTM Network with binary classification
class LSTMDiscriminator(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim):              # Output size is one
        super(LSTMDiscriminator, self).__init__()
        # Embedding Layer
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        # LSTM Layer
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True)
        # Fully Connected Layer
        self.fc = nn.Linear(hidden_dim, 1)  # Output single probability
        # Sigmoid Activation for binary classification
        self.sigmoid = nn.Sigmoid()

    def forward(self, x, hidden=None):
        # Input x shape: torch.Size([10, 49])
        embedded = self.embedding(x)
        # Output Embedding shape: torch.Size([10, 49, 32])
        lstm_out, hidden = self.lstm(embedded, hidden)
        # Output LSTM out shape: torch.Size([10, 49, 64])
        logits = self.fc(lstm_out)
        # Output Logits shape: torch.Size([10, 49, 1])
        prob = self.sigmoid(logits)
        # Output shape Prob: torch.Size([10, 49, 1])
        prob = prob.squeeze(-1)
        # Output shape Prob Squeezed: torch.Size([10, 49])
        return prob, hidden

# %% [markdown]
# $\beta_1:$  Controls the decay rate for the moving average of past gradients. The default value is usually 0.9, but in GANs, it's often set to 0.5. Setting $\beta_1$ to 0.5 can help stabilize GAN training, as it reduces the momentum effect, preventing the optimizer from overshooting or oscillating too much.
#
#
# $\beta_2:$ Controls the decay rate for the moving average of the squared gradients. It affects how the optimizer adjusts the learning rate based on the variance of the past gradients.

# %%
def create_fake_sequences_old(generator, real_sequence, training=False):
    
    ## CREATE FAKE SEQUENCE
    init_real_token = real_sequence[0]
    fake_sequence = [init_real_token]

    ## PLEASE ADJUST WHEN HAVING MULTIPLE LSTM LAYERS
    h_n = torch.zeros(1, 1, 64)
    c_n = torch.zeros(1, 1, 64)
    ##
    
    generator.train() if training else generator.eval()
    
    # If testing, then no gradient calculations
    with torch.no_grad() if not training else contextlib.nullcontext():
        for _ in range(1, len(real_sequence)):
            sequence_input = torch.tensor([fake_sequence[-1]]).unsqueeze(0)
            logits, (h_n, c_n) = generator(sequence_input, (h_n, c_n))
            probs = torch.softmax(logits, dim=-1).squeeze()
            predicted_token = torch.multinomial(probs, num_samples=1).item()
            fake_sequence.append(predicted_token)
    fake_sequence = torch.tensor(fake_sequence[1:]).unsqueeze(0)
    
    return fake_sequence

# %% [markdown]
# GAN TRAINING

# %%
# Instantiate Generator and load the weights
generator = LSTMGenerator(vocab_size=num_bins, embedding_dim=32, hidden_dim=64, output_dim=num_bins)
generator.load_state_dict(torch.load('model_weights.pth'))

# Instantiate Discriminator
discriminator = LSTMDiscriminator(vocab_size=num_bins, embedding_dim=32, hidden_dim=64)

# Loss function
criterion = nn.BCELoss()
# Optimizers
D_optimizer = torch.optim.Adam(discriminator.parameters(), lr=0.0002, betas=(0.5, 0.999))
G_optimizer = torch.optim.Adam(generator.parameters(), lr=0.0002, betas=(0.5, 0.999))

num_epochs = 1000

phi_real_avg_prob = []
phi_fake_avg_prob = []

D_losses = []
G_losses = []

real_seq_during_train = []
fake_seq_during_phi_train = []
fake_seq_during_pi_train = []

for epoch in range(num_epochs):

    # Sample 10 real sequences from the train data
    start_train_idx = np.random.choice(range(len(train_data_temp)-seq_len), size=train_n_seq, replace=True)
    train_data = prep_data(seq_len=seq_len, start_indexes=start_train_idx, data=train_data_temp)
    batch_size = len(train_data)
    
    real_sequences = [torch.tensor(sequence[1:]).unsqueeze(0) for sequence in train_data]
    real_sequences = torch.cat(real_sequences[:batch_size], dim=0)  # Create a batch of real sequences
    
    # Save one sequence per epoch
    real_seq_during_train.append(real_sequences.detach()[0])

    ## ===================
    ## TRAIN DISCRIMINATOR
    ## ===================
    
    # Create Fake sequences in Test mode
    fake_sequences = [create_fake_sequences_old(generator, sequence, training=False) for sequence in train_data]
    fake_sequences = torch.cat(fake_sequences[:batch_size], dim=0)  # Create a batch of fake sequences
    
    fake_seq_during_phi_train.append(fake_sequences.detach()[0])

    # Zero the gradients
    D_optimizer.zero_grad()

    # 1. Train on real sequences (compare to 1, since 1 = real sequence)
    D_real, _ = discriminator(real_sequences)
    final_prob_real = D_real[:,-1]
    D_loss_real = criterion(final_prob_real, torch.ones_like(final_prob_real))

    # 2. Train on fake sequence (compare to 0, since 0 = fake sequence)
    D_fake, _ = discriminator(fake_sequences)
    final_prob_fake = D_fake[:, -1]
    D_loss_fake = criterion(final_prob_fake, torch.zeros_like(final_prob_fake))
    
    # Append avearge probabilites by the Discriminator
    phi_real_avg_prob.append(final_prob_real.detach().mean())
    phi_fake_avg_prob.append(final_prob_fake.detach().mean())

    # Discriminator's Loss and Optimization
    D_loss = (D_loss_real + D_loss_fake) / 2    
    D_loss.backward()
    D_optimizer.step()
    D_losses.append(D_loss.item())

    ## ===============
    ## TRAIN GENERATOR
    ## ===============

    # Zero the gradients
    G_optimizer.zero_grad()

    # Create Fake sequences in Test mode
    fake_sequences = [create_fake_sequences_old(generator, sequence, training=True) for sequence in train_data]
    fake_sequences = torch.cat(fake_sequences[:batch_size], dim=0)  # Create a batch of fake sequences

    fake_seq_during_pi_train.append(fake_sequences.detach()[0])
    
    # Receive the reward
    D_fake, _ = discriminator(fake_sequences)
    final_prob_fake = D_fake[:, -1]

    # Generator's Loss and Optimization
    G_loss = criterion(final_prob_fake, torch.ones_like(final_prob_fake))
    #### G_loss.backward()
    #### G_optimizer.step()
    G_losses.append(G_loss.item())
# Out:
# /var/folders/1x/hjv8bl714_xgsbdy8fp5kj140000gn/T/ipykernel_55641/3339130974.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   generator.load_state_dict(torch.load('model_weights.pth'))

# %%
plt.figure(figsize=(6, 3.5))
plt.plot(G_losses, label='Generators Loss')
plt.plot(D_losses, label='Discriminators Loss')
plt.title("Train Loss")
plt.xlabel("Episode")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(6,3))
plt.plot(phi_real_avg_prob, color='green', label='Real Sequence')
plt.plot(phi_fake_avg_prob, color='red', label='Fake Sequence')
plt.ylim(0,1)
plt.title('Average Probability of Discriminators output \n for Real/Fake Sequences \n (Real should tend to 1, Fake should tend to 0)', size = 12)
plt.legend()
plt.xlabel('Episodes')
plt.ylabel('Probability')
# Out:
# Text(0, 0.5, 'Probability')

# %%
middle_seq = int(len(real_seq_during_train)/2)
end_seq = int(len(real_seq_during_train))

fig, axes = plt.subplots(1, 3, figsize=(15, 3))  # 3 rows, 3 columns, and adjust the size
axes = axes.flatten()
for i in range(3):
    axes[i].plot(real_seq_during_train[i], label='Real Trajectory', color = 'blue')
    axes[i].plot(fake_seq_during_phi_train[i], label='Fake Trajectory D', color = 'lightsteelblue')
    axes[i].plot(fake_seq_during_pi_train[i], label='Fake Trajectory G', color = 'lightsteelblue')
    axes[i].legend()
    axes[i].set_title(f'Trajectory {i+1}')
plt.tight_layout()
plt.show()

fig, axes = plt.subplots(1, 3, figsize=(15, 3))  # 3 rows, 3 columns, and adjust the size
axes = axes.flatten()
for i in range(3):
    axes[i].plot(real_seq_during_train[middle_seq + i], label='Real Trajectory', color = 'blue')
    axes[i].plot(fake_seq_during_phi_train[middle_seq + i], label='Fake Trajectory D', color = 'lightsteelblue')
    axes[i].plot(fake_seq_during_pi_train[middle_seq + i], label='Fake Trajectory G', color = 'lightsteelblue')
    axes[i].legend()
    axes[i].set_title(f'Trajectory {middle_seq+i+1}')
plt.tight_layout()
plt.show()

fig, axes = plt.subplots(1, 3, figsize=(15, 3))  # 3 rows, 3 columns, and adjust the size
axes = axes.flatten()
for i in range(3):
    axes[i].plot(real_seq_during_train[end_seq - 3  + i], label='Real Trajectory', color = 'blue')
    axes[i].plot(fake_seq_during_phi_train[end_seq - 3 + i], label='Fake Trajectory D', color = 'lightsteelblue')
    axes[i].plot(fake_seq_during_pi_train[end_seq - 3 + i], label='Fake Trajectory G', color = 'lightsteelblue')
    axes[i].legend()
    axes[i].set_title(f'Trajectory {end_seq - 3 +i+1}')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Training the GENERATOR
# We create a fake sequence from the **Generator** which serves as an input for the **Discriminator**. The **Discriminator** then outputs the probabilty of being a real sequence (1 = real, 0 = fake). This probabilty is used within the the **Generator** training as a *loss* $BCE(p_{discr}, 1), p_{discr} \in (0,1)$ and compared to 1 since we want to encourage the **Generator** creating realistic sequences which the **Discriminator** would label as real.
#
# $\text{BCE Loss} = - \left[ y \cdot \log(p) + (1 - y) \cdot \log(1 - p) \right]$
#
# Training did not work well since the generator is **NOT TRAINING** at all. The issue: When creating a fake sequence from the **Generator** we sample the next "Token" based on the probability given by the **LSTM** network. Since we sample the Token, we will lose it's connection to the computational graph of the **LSTM** Networks. Therefore when calculating the gradient with **.backward()** and optimizing **optimizer.step()**, the process won't have any computational graph to compute the gradients and update the weigths.
#
# We will now introduce the **Reinforcement learning approach**, which should resolve our issue. We treat the Generator as a **Policy Network** where the states are the input token and the output is a probablity distribution over **actions** (tokens). For each action/token in the sequence, the log probability of the chosen token/action is calculated. For the whole sequence, we sum all the actions (log probabilites) and multiply the **Reward** which is the output of the Discriminator (probablity of the fake sequence being true). The overall loss is the negative of this sum, as we want to increase the likelihood of actions (tokens) that lead to higher rewards.
#
# $\text{Policy Loss} = - \sum_{t=1}^{T} \log\pi_\theta(a_t | s_t) \cdot R$

# %%
def create_fake_sequences(generator, real_sequence, training=False):
    
    init_real_token = real_sequence[0]
    fake_sequence = [init_real_token]
    log_probs = []

    ## PLEASE ADJUST WHEN HAVING MULTIPLE LSTM LAYERS
    h_n = torch.zeros(1, 1, 64)
    c_n = torch.zeros(1, 1, 64)
    ##
    
    generator.train() if training else generator.eval()
    
    # If testing, then no gradient calculations
    with torch.no_grad() if not training else contextlib.nullcontext():

        for _ in range(1, len(real_sequence)):

            sequence_input = torch.tensor([fake_sequence[-1]]).unsqueeze(0)
            logits, (h_n, c_n) = generator(sequence_input, (h_n, c_n))
            probs = torch.softmax(logits, dim=-1).squeeze()
            # Predicted Token
            action = torch.multinomial(probs, num_samples=1)
            # Log probability or the Policy Loss
            log_prob = torch.log(probs[action])
            log_probs.append(log_prob)
            fake_sequence.append(action.item())

    fake_sequence = torch.tensor(fake_sequence[1:]).unsqueeze(0)
    log_probs = torch.cat(log_probs).squeeze(0)
    
    return fake_sequence, log_probs

# %%
# Instantiate Generator and load the weights
generator = LSTMGenerator(vocab_size=num_bins, embedding_dim=32, hidden_dim=64, output_dim=num_bins)
generator.load_state_dict(torch.load('best_model.pth', weights_only=False))

# Instantiate Discriminator
discriminator = LSTMDiscriminator(vocab_size=num_bins, embedding_dim=32, hidden_dim=64)

# Loss function
criterion = nn.BCELoss()
# Optimizers
D_optimizer = torch.optim.Adam(discriminator.parameters(), lr=0.0002, betas=(0.5, 0.999))
G_optimizer = torch.optim.Adam(generator.parameters(), lr=0.0002, betas=(0.5, 0.999))

num_epochs = 1000

phi_real_avg_prob = []
phi_fake_avg_prob = []

D_losses = []
G_losses = []

real_seq_during_train = []
fake_seq_during_phi_train = []
fake_seq_during_pi_train = []

fake_seq_val = []

G_val_loss = []

best_val_loss = float('inf')


for epoch in range(num_epochs):

    # Sample 10 real sequences from the train data
    start_train_idx = np.random.choice(range(len(train_data_temp) - seq_len), size=train_n_seq, replace=True)
    train_data = prep_data(seq_len=seq_len, start_indexes=start_train_idx, data=train_data_temp)
    batch_size = len(train_data)
    
    real_sequences = [torch.tensor(sequence[1:]).unsqueeze(0) for sequence in train_data]
    real_sequences = torch.cat(real_sequences[:batch_size], dim=0)  # Create a batch of real sequences
    
    # Save one sequence per epoch
    real_seq_during_train.append(real_sequences.detach()[0])

    ## ===================
    ## TRAIN DISCRIMINATOR
    ## ===================

    generator.eval()
    discriminator.train()

    # Create Fake sequences in Test mode
    fake_sequences = []
    for sequence in train_data:
        fake_sequence, _ = create_fake_sequences(generator, sequence, training=False)
        fake_sequences.append(fake_sequence)
    fake_sequences = torch.cat(fake_sequences[:batch_size], dim=0)  # Create a batch of fake sequences
    
    fake_seq_during_phi_train.append(fake_sequences.detach()[0])

    # Zero the gradients
    D_optimizer.zero_grad()

    # 1. Train on real sequences (compare to 1, since 1 = real sequence)
    D_real, _ = discriminator(real_sequences)
    final_prob_real = D_real[:, -1]
    D_loss_real = criterion(final_prob_real, torch.ones_like(final_prob_real))

    # 2. Train on fake sequence (compare to 0, since 0 = fake sequence)
    D_fake, _ = discriminator(fake_sequences)
    final_prob_fake = D_fake[:, -1]
    D_loss_fake = criterion(final_prob_fake, torch.zeros_like(final_prob_fake))
    
    # Append avearge probabilites by the Discriminator
    phi_real_avg_prob.append(final_prob_real.detach().mean())
    phi_fake_avg_prob.append(final_prob_fake.detach().mean())

    # Discriminator's Loss and Optimization
    D_loss = (D_loss_real + D_loss_fake) / 2    
    D_loss.backward()
    D_optimizer.step()
    D_losses.append(D_loss.item())

    ## ===============
    ## TRAIN GENERATOR
    ## ===============

    generator.train()
    discriminator.eval()

    # Zero the gradients
    G_optimizer.zero_grad()

    # Create Fake sequences in Test mode
    fake_sequences = []
    log_probs_batch = []
    for sequence in train_data:
        fake_sequence, log_probs = create_fake_sequences(generator, sequence, training=True)
        fake_sequences.append(fake_sequence)
        # Sum log probabilities for the sequence
        log_probs_batch.append(log_probs.sum())

    fake_sequences = torch.cat(fake_sequences[:batch_size], dim=0)
    fake_seq_val.append(fake_sequences.detach()[0])
    
    # Stack the log_probs of the entire batch
    log_probs_batch = torch.stack(log_probs_batch)

    # Receive Reward from the Discriminator
    D_fake, _ = discriminator(fake_sequences)
    rewards = D_fake[:, -1].detach()

    # Calucalte the Policy Loss
    policy_loss = - (log_probs_batch * rewards)
    policy_loss = policy_loss.mean()
    
    # Generator's Loss and Optimization
    policy_loss.backward()
    G_optimizer.step()
    G_losses.append(policy_loss.item())

    ## ===============
    ## EVALUATION
    ## ===============

    generator.eval()
    discriminator.eval()

    batch_size = len(val_data)

    # Create Fake sequences in Test mode
    fake_sequences = []
    log_probs_batch = []

    for sequence in val_data:
        fake_sequence, log_probs = create_fake_sequences(generator, sequence, training=False)
        fake_sequences.append(fake_sequence)
        # Sum log probabilities for the sequence
        log_probs_batch.append(log_probs.sum())

    fake_sequences = torch.cat(fake_sequences[:batch_size], dim=0)
    fake_seq_val.append(fake_sequences.detach()[0])
    
    # Stack the log_probs of the entire batch
    log_probs_batch = torch.stack(log_probs_batch)

    # Receive Reward from the Discriminator
    D_fake, _ = discriminator(fake_sequences)
    rewards = D_fake[:, -1].detach()

    # Calucalte the Policy Loss
    policy_val_loss = - (log_probs_batch * rewards)
    policy_val_loss = policy_val_loss.mean()

    if policy_val_loss < best_val_loss:
        best_val_loss = policy_val_loss
        torch.save(generator.state_dict(), 'model_weights_GAN.pth')

    G_val_loss.append(policy_val_loss.item())

    print('Epoch: ', epoch,'Gen Test Loss: ', policy_loss.item(), 'Gen Val Loss: ', policy_val_loss.item())
# Out:
# Epoch:  0 Gen Test Loss:  67.26172637939453 Gen Val Loss:  65.5211410522461
# Epoch:  1 Gen Test Loss:  65.12527465820312 Gen Val Loss:  64.69252014160156
# Epoch:  2 Gen Test Loss:  67.08442687988281 Gen Val Loss:  66.05386352539062
# Epoch:  3 Gen Test Loss:  66.80291748046875 Gen Val Loss:  65.66572570800781
# Epoch:  4 Gen Test Loss:  67.95384979248047 Gen Val Loss:  66.14715576171875
# Epoch:  5 Gen Test Loss:  66.29795837402344 Gen Val Loss:  66.06758117675781
# Epoch:  6 Gen Test Loss:  68.78886413574219 Gen Val Loss:  65.57247161865234
# Epoch:  7 Gen Test Loss:  68.21748352050781 Gen Val Loss:  66.56417846679688
# Epoch:  8 Gen Test Loss:  65.07981872558594 Gen Val Loss:  66.05281829833984
# Epoch:  9 Gen Test Loss:  67.96647644042969 Gen Val Loss:  66.40131378173828
# Epoch:  10 Gen Test Loss:  63.972007751464844 Gen Val Loss:  66.24181365966797
# Epoch:  11 Gen Test Loss:  66.28703308105469 Gen Val Loss:  66.72938537597656
# Epoch:  12 Gen Test Loss:  68.85194396972656 Gen Val Loss:  66.9013671875
# Epoch:  13 Gen Test Loss:  65.01148986816406 Gen Val Loss:  66.91404724121094
# Epoch:  14 Gen Test Loss:  65.99728393554688 Gen Val Loss:  66.88671875
# Epoch:  15 Gen Test Loss:  67.01829528808594 Gen Val Loss:  66.41242218017578
# Epoch:  16 Gen Test Loss:  65.29705047607422 Gen Val Loss:  66.91901397705078
# Epoch:  17 Gen Test Loss:  67.01229095458984 Gen Val Loss:  66.26366424560547
# Epoch:  18 Gen Test Loss:  65.62610626220703 Gen Val Loss:  66.76319122314453
# Epoch:  19 Gen Test Loss:  65.53956604003906 Gen Val Loss:  68.0180892944336
# Epoch:  20 Gen Test Loss:  69.55367279052734 Gen Val Loss:  68.22142791748047
# Epoch:  21 Gen Test Loss:  66.92646026611328 Gen Val Loss:  66.34474182128906
# Epoch:  22 Gen Test Loss:  68.09832763671875 Gen Val Loss:  67.84664154052734
# Epoch:  23 Gen Test Loss:  67.55036163330078 Gen Val Loss:  67.25520324707031
# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 3.5))

# Generator's Loss in the first subplot
axs[0].plot(G_losses, label="Generator's Train Loss")
axs[0].plot(G_val_loss, label="Generator's Validation Loss")
axs[0].set_title("Generator's Loss")
axs[0].set_xlabel("Episode")
axs[0].set_ylabel("Loss")
axs[0].legend()
# Discriminator's Loss
axs[1].plot(D_losses, color='orange', label="Discriminator's Loss")
axs[1].set_title("Discriminator's Loss")
axs[1].set_ylim(0,1)
axs[1].set_xlabel("Episode")
axs[1].set_ylabel("Loss")
axs[1].legend()

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,3))
plt.plot(phi_real_avg_prob, color='green', label='Real Sequence')
plt.plot(phi_fake_avg_prob, color='red', label='Fake Sequence')
plt.ylim(0,1)
plt.title('Average Probability of Discriminators output \n for Real/Fake Sequences \n (Real should tend to 1, Fake should tend to 0)', size = 12)
plt.legend()
plt.xlabel('Episodes')
plt.ylabel('Probability')
# Out:
# Text(0, 0.5, 'Probability')

# %%
generator_val = LSTMGenerator(vocab_size=num_bins, embedding_dim=32, hidden_dim=64, output_dim=num_bins)
generator_val.load_state_dict(torch.load('model_weights_GAN.pth', weights_only=False))

generator_val.eval()
val_loss = []
val_perplexity = []
# No weight updates
with torch.no_grad():
    
    for sequence in val_data:
        
        sequence_input = torch.tensor(sequence[:-1]).unsqueeze(0)   # Exclude last token
        targets = torch.tensor(sequence[1:]).unsqueeze(0)           # Exclude first token
        logits, _ = generator_val(sequence_input)  # Forward pass
        logits = logits.view(-1, logits.size(-1))  # Shape: [49, 30]
        targets = targets.view(-1)  # Shape: [49] 
        
        # Cross entropy Loss
        loss = criterion(logits, targets)
        val_loss.append(loss.item())

        # Log probabilities
        log_probs = F.log_softmax(logits, dim=-1)
        target_log_probs = log_probs[range(len(targets)), targets]

        # Perplexity: exp(-average log probability)
        avg_log_prob = target_log_probs.mean()
        perplexity = torch.exp(-avg_log_prob).item()
        val_perplexity.append(perplexity)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[31], line 2
#       1 generator_val = LSTMGenerator(vocab_size=num_bins, embedding_dim=32, hidden_dim=64, output_dim=num_bins)
# ----> 2 generator_val.load_state_dict(torch.load('model_weights_GAN.pth', weights_only=False))
#       4 generator_val.eval()
#       5 val_loss = []
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/serialization.py:1065, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1062 if 'encoding' not in pickle_load_args.keys():
#    1063     pickle_load_args['encoding'] = 'utf-8'
# -> 1065 with _open_file_like(f, 'rb') as opened_file:
#    1066     if _is_zipfile(opened_file):
#    1067         # The zipfile reader is going to advance the current file position.
#    1068         # If we want to actually tail call to torch.jit.load, we need to
#    1069         # reset back to the original position.
#    1070         orig_position = opened_file.tell()
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/serialization.py:468, in _open_file_like(name_or_buffer, mode)
#     466 def _open_file_like(name_or_buffer, mode):
#     467     if _is_path(name_or_buffer):
# --> 468         return _open_file(name_or_buffer, mode)
#     469     else:
#     470         if 'w' in mode:
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/serialization.py:449, in _open_file.__init__(self, name, mode)
#     448 def __init__(self, name, mode):
# --> 449     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'model_weights_GAN.pth'

# %%
generator_test = LSTMModel(vocab_size=num_bins, embedding_dim=32, hidden_dim=64, output_dim=num_bins)
generator_test.load_state_dict(torch.load('model_weights_GAN.pth', weights_only=False))

## TEST DATA
generator_test.eval()
test_loss = []
test_perplexity = []

# No weight updates
with torch.no_grad():
    
    for sequence in test_data:
        
        sequence_input = torch.tensor(sequence[:-1]).unsqueeze(0)   # Exclude last token
        targets = torch.tensor(sequence[1:]).unsqueeze(0)           # Exclude first token
        logits, _ = generator_test(sequence_input)  # Forward pass
        logits = logits.view(-1, logits.size(-1))  # Shape: [49, 30]
        targets = targets.view(-1)  # Shape: [49] 
        
        # Cross entropy Loss
        loss = criterion(logits, targets)
        test_loss.append(loss.item())

        # Log probabilities
        log_probs = F.log_softmax(logits, dim=-1)
        target_log_probs = log_probs[range(len(targets)), targets]

        # Perplexity: exp(-average log probability)
        avg_log_prob = target_log_probs.mean()
        perplexity = torch.exp(-avg_log_prob).item()
        test_perplexity.append(perplexity)

# %%
val_perplexity = np.array(val_perplexity)
test_perplexity = np.array(test_perplexity)

mean_test = np.mean(test_perplexity)
mean_val = np.mean(val_perplexity)

fig, axs = plt.subplots(1, 2, figsize=(10, 3))

# Plot 1: Validation & Test Loss
axs[0].plot(val_loss, label='Validation Loss', color='orange')
axs[0].plot(test_loss, label='Test Loss', color='darkblue')
axs[0].legend()
axs[0].set_title('Validation & Test Loss for the Best Model (Teacher Forcing)', size=10)
axs[0].set_xlabel('# of Sequences')
axs[0].set_ylabel('Loss')
axs[0].set_ylim(0, 2)

# Plot 2: Histogram of Perplexity Distribution
axs[1].hist(val_perplexity, color='orange', bins=10, alpha=0.7, label='Validation Perplexity')
axs[1].hist(test_perplexity, color='darkblue', bins=10, alpha=0.7, label='Test Perplexity')
axs[1].set_title('Validation & Test Data: Perplexity Distribution', size=10)
axs[1].set_xlabel('Sequence Perplexity')
axs[1].set_ylabel('Frequency')
axs[1].set_xlim(0, 5)

# Vertical lines for the mean values on the histogram
axs[1].axvline(mean_val, color='red', linewidth=1, linestyle='dashed')
axs[1].axvline(mean_test, color='red', linewidth=1, linestyle='dashed')
axs[1].text(mean_val-2.0, axs[1].get_ylim()[1] * 0.9, f'Mean Validation: {mean_val:.2f}', color='red')
axs[1].text(mean_test+0.1, axs[1].get_ylim()[1] * 0.9, f'Mean Test: {mean_test:.2f}', color='red')

plt.tight_layout()
plt.show()

# %%
middle_seq = int(len(real_seq_during_train)/2)
end_seq = int(len(real_seq_during_train))

fig, axes = plt.subplots(1, 3, figsize=(15, 3))  # 3 rows, 3 columns, and adjust the size
axes = axes.flatten()
for i in range(3):
    axes[i].plot(real_seq_during_train[i], label='Real Trajectory', color = 'blue')
    axes[i].plot(fake_seq_during_phi_train[i], label='Fake Trajectory D', color = 'lightsteelblue')
    axes[i].plot(fake_seq_during_pi_train[i], label='Fake Trajectory G', color = 'lightsteelblue')
    axes[i].legend()
    axes[i].set_title(f'Trajectory {i+1}')
plt.tight_layout()
plt.show()

fig, axes = plt.subplots(1, 3, figsize=(15, 3))  # 3 rows, 3 columns, and adjust the size
axes = axes.flatten()
for i in range(3):
    axes[i].plot(real_seq_during_train[middle_seq + i], label='Real Trajectory', color = 'blue')
    axes[i].plot(fake_seq_during_phi_train[middle_seq + i], label='Fake Trajectory D', color = 'lightsteelblue')
    axes[i].plot(fake_seq_during_pi_train[middle_seq + i], label='Fake Trajectory G', color = 'lightsteelblue')
    axes[i].legend()
    axes[i].set_title(f'Trajectory {middle_seq+i+1}')
plt.tight_layout()
plt.show()

fig, axes = plt.subplots(1, 3, figsize=(15, 3))  # 3 rows, 3 columns, and adjust the size
axes = axes.flatten()
for i in range(3):
    axes[i].plot(real_seq_during_train[end_seq - 3  + i], label='Real Trajectory', color = 'blue')
    axes[i].plot(fake_seq_during_phi_train[end_seq - 3 + i], label='Fake Trajectory D', color = 'lightsteelblue')
    axes[i].plot(fake_seq_during_pi_train[end_seq - 3 + i], label='Fake Trajectory G', color = 'lightsteelblue')
    axes[i].legend()
    axes[i].set_title(f'Trajectory {end_seq - 3 +i+1}')
plt.tight_layout()
plt.show()

# %%
def check_gradients(model):
    grads = []
    for name, param in model.named_parameters():
        # Print the first 5 weights for each parameter
        print(f"{name} - First 5 weights: {param.data.view(-1)[:5]}")
        
        if param.grad is not None:
            grads.append(param.grad.abs().sum().item())
        else:
            grads.append(None)
    
    return grads

# %%
# Instantiate Generator and load the weights
generator = LSTMGenerator(vocab_size=num_bins, embedding_dim=32, hidden_dim=64, output_dim=num_bins)
generator.load_state_dict(torch.load('model_weights.pth', weights_only=False))

# Instantiate Discriminator
discriminator = LSTMDiscriminator(vocab_size=num_bins, embedding_dim=32, hidden_dim=64)

# Loss function
criterion = nn.BCELoss()
# Optimizers
D_optimizer = torch.optim.Adam(discriminator.parameters(), lr=0.0002, betas=(0.5, 0.999))
G_optimizer = torch.optim.Adam(generator.parameters(), lr=0.0002, betas=(0.5, 0.999))

num_epochs = 1000

phi_real_avg_prob = []
phi_fake_avg_prob = []

D_losses = []
G_losses = []

real_seq_during_train = []
fake_seq_during_phi_train = []
fake_seq_during_pi_train = []

for epoch in range(num_epochs):

    # Sample 10 real sequences from the train data
    start_train_idx = np.random.choice(range(len(train_data_temp) - seq_len), size=train_n_seq, replace=True)
    train_data = prep_data(seq_len=seq_len, start_indexes=start_train_idx, data=train_data_temp)
    batch_size = len(train_data)
    
    real_sequences = [torch.tensor(sequence[1:]).unsqueeze(0) for sequence in train_data]
    real_sequences = torch.cat(real_sequences[:batch_size], dim=0)  # Create a batch of real sequences
    
    # Save one sequence per epoch
    real_seq_during_train.append(real_sequences.detach()[0])

    ## ===================
    ## TRAIN DISCRIMINATOR
    ## ===================

    # Create Fake sequences in Test mode
    fake_sequences = []
    for sequence in train_data:
        fake_sequence, _ = create_fake_sequences(generator, sequence, training=False)
        fake_sequences.append(fake_sequence)
    fake_sequences = torch.cat(fake_sequences[:batch_size], dim=0)  # Create a batch of fake sequences
    
    fake_seq_during_phi_train.append(fake_sequences.detach()[0])

    # Zero the gradients
    D_optimizer.zero_grad()

    # 1. Train on real sequences (compare to 1, since 1 = real sequence)
    D_real, _ = discriminator(real_sequences)
    final_prob_real = D_real[:, -1]
    D_loss_real = criterion(final_prob_real, torch.ones_like(final_prob_real))

    # 2. Train on fake sequence (compare to 0, since 0 = fake sequence)
    D_fake, _ = discriminator(fake_sequences)
    final_prob_fake = D_fake[:, -1]
    D_loss_fake = criterion(final_prob_fake, torch.zeros_like(final_prob_fake))
    
    # Append avearge probabilites by the Discriminator
    phi_real_avg_prob.append(final_prob_real.detach().mean())
    phi_fake_avg_prob.append(final_prob_fake.detach().mean())


    print('DISCRIMINATOR TRAINING')
    print('')
    print("DISCRIMINATOR Gradients before backpropagation (should be None):")
    print(check_gradients(discriminator))

    print('')
    print("GENERATOR Gradients within discriminator training (should be None):")
    print(check_gradients(generator))

    # Discriminator's Loss and Optimization
    D_loss = (D_loss_real + D_loss_fake) / 2    
    D_loss.backward()
    D_optimizer.step()
    D_losses.append(D_loss.item())

    print('')
    print("DISCRIMINATOR after backpropagation (should be NOT None):")
    print(check_gradients(discriminator))

    print('')
    print("GENERATOR Gradients within discriminator training (should be None):")
    print(check_gradients(generator))

    ## ===============
    ## TRAIN GENERATOR
    ## ===============

    # Zero the gradients
    G_optimizer.zero_grad()

    # Create Fake sequences in Test mode
    fake_sequences = []
    log_probs_batch = []
    for sequence in train_data:
        fake_sequence, log_probs = create_fake_sequences(generator, sequence, training=True)
        fake_sequences.append(fake_sequence)
        # Sum log probabilities for the sequence
        log_probs_batch.append(log_probs.sum())

    fake_sequences = torch.cat(fake_sequences[:batch_size], dim=0)
    fake_seq_during_pi_train.append(fake_sequences.detach()[0])
    
    # Stack the log_probs of the entire batch
    log_probs_batch = torch.stack(log_probs_batch)
    
    # Receive Reward from the Discriminator
    D_fake, _ = discriminator(fake_sequences)
    rewards = D_fake[:, -1].detach()

    # Calucalte the Policy Loss
    policy_loss = - (log_probs_batch * rewards)
    policy_loss = policy_loss.mean()

    print('')
    print('')

    print('GENERATOR TRAINING')

    print('')
    print("GENERATOR before backpropagation (should be None):")
    print(check_gradients(generator))

    print('')
    print("DISCRIMINATOR Gradients within generator training (prior) (should stay the same):")
    print(check_gradients(discriminator))
    
    # Generator's Loss and Optimization
    policy_loss.backward()
    G_optimizer.step()
    G_losses.append(policy_loss.item())

    print('')
    print("GENERATOR after backpropagation (should be NOT None):")
    print(check_gradients(generator))

    print('')
    print("DISCRIMINATOR Gradients within generator training (should stay the same):")
    print(check_gradients(discriminator))


    break

    #print(f'Epoch [{epoch+1}/{num_epochs}] | D Loss: {D_loss.item():.4f} | G Loss: {policy_loss.item():.4f}')
# Out:
# DISCRIMINATOR TRAINING
#
# DISCRIMINATOR Gradients before backpropagation (should be None):
# embedding.weight - First 5 weights: tensor([-1.0924,  1.2170, -1.4851, -0.3217, -1.7958])
# lstm.weight_ih_l0 - First 5 weights: tensor([ 0.0448, -0.0333,  0.0601, -0.0336,  0.0797])
# lstm.weight_hh_l0 - First 5 weights: tensor([ 0.0338,  0.0410, -0.0628,  0.0859, -0.0925])
# lstm.bias_ih_l0 - First 5 weights: tensor([ 0.0218, -0.0206, -0.0861, -0.0554, -0.0619])
# lstm.bias_hh_l0 - First 5 weights: tensor([ 0.1035, -0.1234, -0.0151,  0.0602,  0.0853])
# fc.weight - First 5 weights: tensor([-0.0479,  0.1188,  0.0527,  0.1174,  0.1079])
# fc.bias - First 5 weights: tensor([-0.0044])
# [None, None, None, None, None, None, None]
#
# GENERATOR Gradients within discriminator training (should be None):
# embedding.weight - First 5 weights: tensor([ 1.7816, -0.0954,  2.0137, -0.3664, -2.1872])
# lstm.weight_ih_l0 - First 5 weights: tensor([-0.1041,  0.1400,  0.2199, -0.0798,  0.0279])
# lstm.weight_hh_l0 - First 5 weights: tensor([ 0.0395, -0.1772, -0.1330,  0.0340,  0.0716])
# lstm.bias_ih_l0 - First 5 weights: tensor([0.3520, 0.2985, 0.2947, 0.1836, 0.2834])
# lstm.bias_hh_l0 - First 5 weights: tensor([0.2503, 0.2273, 0.3029, 0.3207, 0.2178])
# fc.weight - First 5 weights: tensor([ 0.1333,  0.2189,  0.1285, -0.0518, -0.1717])
# fc.bias - First 5 weights: tensor([-0.2139, -0.0884, -0.0943, -0.2638, -0.1905])
# [None, None, None, None, None, None, None]
#
# DISCRIMINATOR after backpropagation (should be NOT None):
# embedding.weight - First 5 weights: tensor([-1.0924,  1.2170, -1.4851, -0.3217, -1.7958])
# lstm.weight_ih_l0 - First 5 weights: tensor([ 0.0446, -0.0335,  0.0603, -0.0334,  0.0799])
# lstm.weight_hh_l0 - First 5 weights: tensor([ 0.0336,  0.0408, -0.0630,  0.0861, -0.0923])
# lstm.bias_ih_l0 - First 5 weights: tensor([ 0.0216, -0.0208, -0.0859, -0.0552, -0.0617])
# lstm.bias_hh_l0 - First 5 weights: tensor([ 0.1033, -0.1236, -0.0149,  0.0604,  0.0855])
# fc.weight - First 5 weights: tensor([-0.0477,  0.1186,  0.0529,  0.1176,  0.1081])
# fc.bias - First 5 weights: tensor([-0.0046])
# [0.17169032990932465, 7.965115547180176, 2.017714500427246, 0.15354236960411072, 0.15354235470294952, 0.9111320972442627, 0.000560268759727478]
#
# GENERATOR Gradients within discriminator training (should be None):
# embedding.weight - First 5 weights: tensor([ 1.7816, -0.0954,  2.0137, -0.3664, -2.1872])
# lstm.weight_ih_l0 - First 5 weights: tensor([-0.1041,  0.1400,  0.2199, -0.0798,  0.0279])
# lstm.weight_hh_l0 - First 5 weights: tensor([ 0.0395, -0.1772, -0.1330,  0.0340,  0.0716])
# lstm.bias_ih_l0 - First 5 weights: tensor([0.3520, 0.2985, 0.2947, 0.1836, 0.2834])
# lstm.bias_hh_l0 - First 5 weights: tensor([0.2503, 0.2273, 0.3029, 0.3207, 0.2178])
# fc.weight - First 5 weights: tensor([ 0.1333,  0.2189,  0.1285, -0.0518, -0.1717])
# fc.bias - First 5 weights: tensor([-0.2139, -0.0884, -0.0943, -0.2638, -0.1905])
# [None, None, None, None, None, None, None]
#
#
# GENERATOR TRAINING
#
# GENERATOR before backpropagation (should be None):
# embedding.weight - First 5 weights: tensor([ 1.7816, -0.0954,  2.0137, -0.3664, -2.1872])
# lstm.weight_ih_l0 - First 5 weights: tensor([-0.1041,  0.1400,  0.2199, -0.0798,  0.0279])
# lstm.weight_hh_l0 - First 5 weights: tensor([ 0.0395, -0.1772, -0.1330,  0.0340,  0.0716])
# lstm.bias_ih_l0 - First 5 weights: tensor([0.3520, 0.2985, 0.2947, 0.1836, 0.2834])
# lstm.bias_hh_l0 - First 5 weights: tensor([0.2503, 0.2273, 0.3029, 0.3207, 0.2178])
# fc.weight - First 5 weights: tensor([ 0.1333,  0.2189,  0.1285, -0.0518, -0.1717])
# fc.bias - First 5 weights: tensor([-0.2139, -0.0884, -0.0943, -0.2638, -0.1905])
# [None, None, None, None, None, None, None]
#
# DISCRIMINATOR Gradients within generator training (prior) (should stay the same):
# embedding.weight - First 5 weights: tensor([-1.0924,  1.2170, -1.4851, -0.3217, -1.7958])
# lstm.weight_ih_l0 - First 5 weights: tensor([ 0.0446, -0.0335,  0.0603, -0.0334,  0.0799])
# lstm.weight_hh_l0 - First 5 weights: tensor([ 0.0336,  0.0408, -0.0630,  0.0861, -0.0923])
# lstm.bias_ih_l0 - First 5 weights: tensor([ 0.0216, -0.0208, -0.0859, -0.0552, -0.0617])
# lstm.bias_hh_l0 - First 5 weights: tensor([ 0.1033, -0.1236, -0.0149,  0.0604,  0.0855])
# fc.weight - First 5 weights: tensor([-0.0477,  0.1186,  0.0529,  0.1176,  0.1081])
# fc.bias - First 5 weights: tensor([-0.0046])
# [0.17169032990932465, 7.965115547180176, 2.017714500427246, 0.15354236960411072, 0.15354235470294952, 0.9111320972442627, 0.000560268759727478]
#
# GENERATOR after backpropagation (should be NOT None):
# embedding.weight - First 5 weights: tensor([ 1.7816, -0.0954,  2.0137, -0.3664, -2.1872])
# lstm.weight_ih_l0 - First 5 weights: tensor([-0.1039,  0.1398,  0.2197, -0.0796,  0.0281])
# lstm.weight_hh_l0 - First 5 weights: tensor([ 0.0395, -0.1772, -0.1330,  0.0340,  0.0716])
# lstm.bias_ih_l0 - First 5 weights: tensor([0.3522, 0.2983, 0.2949, 0.1834, 0.2832])
# lstm.bias_hh_l0 - First 5 weights: tensor([0.2505, 0.2271, 0.3031, 0.3205, 0.2176])
# fc.weight - First 5 weights: tensor([ 0.1335,  0.2191,  0.1287, -0.0516, -0.1719])
# fc.bias - First 5 weights: tensor([-0.2141, -0.0886, -0.0941, -0.2636, -0.1903])
# [9.585888862609863, 127.09239196777344, 0.0, 3.5711770057678223, 3.5711770057678223, 73.92668914794922, 2.8830292224884033]
#
# DISCRIMINATOR Gradients within generator training (should stay the same):
# embedding.weight - First 5 weights: tensor([-1.0924,  1.2170, -1.4851, -0.3217, -1.7958])
# lstm.weight_ih_l0 - First 5 weights: tensor([ 0.0446, -0.0335,  0.0603, -0.0334,  0.0799])
# lstm.weight_hh_l0 - First 5 weights: tensor([ 0.0336,  0.0408, -0.0630,  0.0861, -0.0923])
# lstm.bias_ih_l0 - First 5 weights: tensor([ 0.0216, -0.0208, -0.0859, -0.0552, -0.0617])
# lstm.bias_hh_l0 - First 5 weights: tensor([ 0.1033, -0.1236, -0.0149,  0.0604,  0.0855])
# fc.weight - First 5 weights: tensor([-0.0477,  0.1186,  0.0529,  0.1176,  0.1081])
# fc.bias - First 5 weights: tensor([-0.0046])
# [0.17169032990932465, 7.965115547180176, 2.017714500427246, 0.15354236960411072, 0.15354235470294952, 0.9111320972442627, 0.000560268759727478]

# %%
def create_fake_sequences_old(generator, real_sequence, training=False):
    
    init_real_token = real_sequence[0]
    fake_sequence = [init_real_token]
    log_probs = []

    ## PLEASE ADJUST WHEN HAVING MULTIPLE LSTM LAYERS
    h_n = torch.zeros(1, 1, 64)
    c_n = torch.zeros(1, 1, 64)
    ##
    
    generator.train() if training else generator.eval()
    
    # If testing, then no gradient calculations
    with torch.no_grad() if not training else contextlib.nullcontext():

        for _ in range(1, len(real_sequence)):

            sequence_input = torch.tensor([fake_sequence[-1]]).unsqueeze(0)
            logits, (h_n, c_n) = generator(sequence_input, (h_n, c_n))
            probs = torch.softmax(logits, dim=-1).squeeze()
            # Predicted Token
            action = torch.multinomial(probs, num_samples=1)
            # Log probability or the Policy Loss
            log_prob = torch.log(probs[action])
            log_probs.append(log_prob)
            fake_sequence.append(action.item())

    fake_sequence = torch.tensor(fake_sequence[1:]).unsqueeze(0)
    log_probs = torch.cat(log_probs).squeeze(0)
    
    return fake_sequence

# %%
# Instantiate Generator and load the weights
generator = LSTMGenerator(vocab_size=num_bins, embedding_dim=32, hidden_dim=64, output_dim=num_bins)
generator.load_state_dict(torch.load('model_weights.pth', weights_only=False))

# Instantiate Discriminator
discriminator = LSTMDiscriminator(vocab_size=num_bins, embedding_dim=32, hidden_dim=64)

# Loss function
criterion = nn.BCELoss()
# Optimizers
D_optimizer = torch.optim.Adam(discriminator.parameters(), lr=0.0002, betas=(0.5, 0.999))
G_optimizer = torch.optim.Adam(generator.parameters(), lr=0.0002, betas=(0.5, 0.999))

num_epochs = 1000

phi_real_avg_prob = []
phi_fake_avg_prob = []

D_losses = []
G_losses = []

real_seq_during_train = []
fake_seq_during_phi_train = []
fake_seq_during_pi_train = []

for epoch in range(num_epochs):

    # Sample 10 real sequences from the train data
    start_train_idx = np.random.choice(range(len(train_data_temp)-seq_len), size=train_n_seq, replace=True)
    train_data = prep_data(seq_len=seq_len, start_indexes=start_train_idx, data=train_data_temp)
    batch_size = len(train_data)
    
    real_sequences = [torch.tensor(sequence[1:]).unsqueeze(0) for sequence in train_data]
    real_sequences = torch.cat(real_sequences[:batch_size], dim=0)  # Create a batch of real sequences
    
    # Save one sequence per epoch
    real_seq_during_train.append(real_sequences.detach()[0])

    ## ===================
    ## TRAIN DISCRIMINATOR
    ## ===================
    
    # Create Fake sequences in Test mode
    fake_sequences = [create_fake_sequences_old(generator, sequence, training=False) for sequence in train_data]
    fake_sequences = torch.cat(fake_sequences[:batch_size], dim=0)  # Create a batch of fake sequences
    
    fake_seq_during_phi_train.append(fake_sequences.detach()[0])

    # Zero the gradients
    D_optimizer.zero_grad()

    # 1. Train on real sequences (compare to 1, since 1 = real sequence)
    D_real, _ = discriminator(real_sequences)
    final_prob_real = D_real[:,-1]
    D_loss_real = criterion(final_prob_real, torch.ones_like(final_prob_real))

    # 2. Train on fake sequence (compare to 0, since 0 = fake sequence)
    D_fake, _ = discriminator(fake_sequences)
    final_prob_fake = D_fake[:, -1]
    D_loss_fake = criterion(final_prob_fake, torch.zeros_like(final_prob_fake))
    
    # Append avearge probabilites by the Discriminator
    phi_real_avg_prob.append(final_prob_real.detach().mean())
    phi_fake_avg_prob.append(final_prob_fake.detach().mean())

    print('DISCRIMINATOR TRAINING')
    print('')
    print("DISCRIMINATOR Gradients before backpropagation (should be None):")
    print(check_gradients(discriminator))

    print('')
    print("GENERATOR Gradients within discriminator training (should be None):")
    print(check_gradients(generator))

    # Discriminator's Loss and Optimization
    D_loss = (D_loss_real + D_loss_fake) / 2    
    D_loss.backward()
    D_optimizer.step()
    D_losses.append(D_loss.item())
    
    print('')
    print("DISCRIMINATOR after backpropagation (should be NOT None):")
    print(check_gradients(discriminator))

    print('')
    print("GENERATOR Gradients within discriminator training (should be None):")
    print(check_gradients(generator))

    ## ===============
    ## TRAIN GENERATOR
    ## ===============

    # Zero the gradients
    G_optimizer.zero_grad()

    # Create Fake sequences in Test mode
    fake_sequences = [create_fake_sequences_old(generator, sequence, training=True) for sequence in train_data]
    fake_sequences = torch.cat(fake_sequences[:batch_size], dim=0)  # Create a batch of fake sequences

    fake_seq_during_pi_train.append(fake_sequences.detach()[0])
    
    # Receive the reward
    D_fake, _ = discriminator(fake_sequences)
    final_prob_fake = D_fake[:, -1]
    
    print('')
    print('')

    print('GENERATOR TRAINING')

    print('')
    print("GENERATOR before backpropagation (should be None):")
    print(check_gradients(generator))

    print('')
    print("DISCRIMINATOR Gradients within generator training (prior) (should stay the same):")
    print(check_gradients(discriminator))

    # Generator's Loss and Optimization
    G_loss = criterion(final_prob_fake, torch.ones_like(final_prob_fake))
    G_loss.backward()
    G_optimizer.step()
    G_losses.append(G_loss.item())

    print('')
    print("GENERATOR after backpropagation (should be NOT None):")
    print(check_gradients(generator))

    print('')
    print("DISCRIMINATOR Gradients within generator training (should stay the same):")
    print(check_gradients(discriminator))

    break
# Out:
# DISCRIMINATOR TRAINING
#
# DISCRIMINATOR Gradients before backpropagation (should be None):
# embedding.weight - First 5 weights: tensor([ 0.2777,  0.1662,  0.2462,  0.2507, -0.0435])
# lstm.weight_ih_l0 - First 5 weights: tensor([ 0.0600,  0.0246, -0.0497, -0.1156, -0.0083])
# lstm.weight_hh_l0 - First 5 weights: tensor([-0.0957,  0.1230,  0.0502, -0.0378, -0.0073])
# lstm.bias_ih_l0 - First 5 weights: tensor([-0.0014,  0.1157,  0.0116, -0.0881, -0.0213])
# lstm.bias_hh_l0 - First 5 weights: tensor([ 0.0414,  0.1168,  0.0935, -0.0812, -0.1090])
# fc.weight - First 5 weights: tensor([-0.0961,  0.0367, -0.0700,  0.1136,  0.0999])
# fc.bias - First 5 weights: tensor([0.0868])
# [None, None, None, None, None, None, None]
#
# GENERATOR Gradients within discriminator training (should be None):
# embedding.weight - First 5 weights: tensor([ 1.7816, -0.0954,  2.0137, -0.3664, -2.1872])
# lstm.weight_ih_l0 - First 5 weights: tensor([-0.1041,  0.1400,  0.2199, -0.0798,  0.0279])
# lstm.weight_hh_l0 - First 5 weights: tensor([ 0.0395, -0.1772, -0.1330,  0.0340,  0.0716])
# lstm.bias_ih_l0 - First 5 weights: tensor([0.3520, 0.2985, 0.2947, 0.1836, 0.2834])
# lstm.bias_hh_l0 - First 5 weights: tensor([0.2503, 0.2273, 0.3029, 0.3207, 0.2178])
# fc.weight - First 5 weights: tensor([ 0.1333,  0.2189,  0.1285, -0.0518, -0.1717])
# fc.bias - First 5 weights: tensor([-0.2139, -0.0884, -0.0943, -0.2638, -0.1905])
# [None, None, None, None, None, None, None]
#
# DISCRIMINATOR after backpropagation (should be NOT None):
# embedding.weight - First 5 weights: tensor([ 0.2777,  0.1662,  0.2462,  0.2507, -0.0435])
# lstm.weight_ih_l0 - First 5 weights: tensor([ 0.0598,  0.0248, -0.0499, -0.1158, -0.0085])
# lstm.weight_hh_l0 - First 5 weights: tensor([-0.0959,  0.1232,  0.0500, -0.0380, -0.0075])
# lstm.bias_ih_l0 - First 5 weights: tensor([-0.0016,  0.1155,  0.0114, -0.0879, -0.0215])
# lstm.bias_hh_l0 - First 5 weights: tensor([ 0.0412,  0.1166,  0.0933, -0.0810, -0.1092])
# fc.weight - First 5 weights: tensor([-0.0959,  0.0365, -0.0698,  0.1138,  0.0997])
# fc.bias - First 5 weights: tensor([0.0866])
# [0.1297769397497177, 5.643371105194092, 2.2574405670166016, 0.15063491463661194, 0.15063491463661194, 0.7426745891571045, 0.01853986084461212]
#
# GENERATOR Gradients within discriminator training (should be None):
# embedding.weight - First 5 weights: tensor([ 1.7816, -0.0954,  2.0137, -0.3664, -2.1872])
# lstm.weight_ih_l0 - First 5 weights: tensor([-0.1041,  0.1400,  0.2199, -0.0798,  0.0279])
# lstm.weight_hh_l0 - First 5 weights: tensor([ 0.0395, -0.1772, -0.1330,  0.0340,  0.0716])
# lstm.bias_ih_l0 - First 5 weights: tensor([0.3520, 0.2985, 0.2947, 0.1836, 0.2834])
# lstm.bias_hh_l0 - First 5 weights: tensor([0.2503, 0.2273, 0.3029, 0.3207, 0.2178])
# fc.weight - First 5 weights: tensor([ 0.1333,  0.2189,  0.1285, -0.0518, -0.1717])
# fc.bias - First 5 weights: tensor([-0.2139, -0.0884, -0.0943, -0.2638, -0.1905])
# [None, None, None, None, None, None, None]
#
#
# GENERATOR TRAINING
#
# GENERATOR before backpropagation (should be None):
# embedding.weight - First 5 weights: tensor([ 1.7816, -0.0954,  2.0137, -0.3664, -2.1872])
# lstm.weight_ih_l0 - First 5 weights: tensor([-0.1041,  0.1400,  0.2199, -0.0798,  0.0279])
# lstm.weight_hh_l0 - First 5 weights: tensor([ 0.0395, -0.1772, -0.1330,  0.0340,  0.0716])
# lstm.bias_ih_l0 - First 5 weights: tensor([0.3520, 0.2985, 0.2947, 0.1836, 0.2834])
# lstm.bias_hh_l0 - First 5 weights: tensor([0.2503, 0.2273, 0.3029, 0.3207, 0.2178])
# fc.weight - First 5 weights: tensor([ 0.1333,  0.2189,  0.1285, -0.0518, -0.1717])
# fc.bias - First 5 weights: tensor([-0.2139, -0.0884, -0.0943, -0.2638, -0.1905])
# [None, None, None, None, None, None, None]
#
# DISCRIMINATOR Gradients within generator training (prior) (should stay the same):
# embedding.weight - First 5 weights: tensor([ 0.2777,  0.1662,  0.2462,  0.2507, -0.0435])
# lstm.weight_ih_l0 - First 5 weights: tensor([ 0.0598,  0.0248, -0.0499, -0.1158, -0.0085])
# lstm.weight_hh_l0 - First 5 weights: tensor([-0.0959,  0.1232,  0.0500, -0.0380, -0.0075])
# lstm.bias_ih_l0 - First 5 weights: tensor([-0.0016,  0.1155,  0.0114, -0.0879, -0.0215])
# lstm.bias_hh_l0 - First 5 weights: tensor([ 0.0412,  0.1166,  0.0933, -0.0810, -0.1092])
# fc.weight - First 5 weights: tensor([-0.0959,  0.0365, -0.0698,  0.1138,  0.0997])
# fc.bias - First 5 weights: tensor([0.0866])
# [0.1297769397497177, 5.643371105194092, 2.2574405670166016, 0.15063491463661194, 0.15063491463661194, 0.7426745891571045, 0.01853986084461212]
#
# GENERATOR after backpropagation (should be NOT None):
# embedding.weight - First 5 weights: tensor([ 1.7816, -0.0954,  2.0137, -0.3664, -2.1872])
# lstm.weight_ih_l0 - First 5 weights: tensor([-0.1041,  0.1400,  0.2199, -0.0798,  0.0279])
# lstm.weight_hh_l0 - First 5 weights: tensor([ 0.0395, -0.1772, -0.1330,  0.0340,  0.0716])
# lstm.bias_ih_l0 - First 5 weights: tensor([0.3520, 0.2985, 0.2947, 0.1836, 0.2834])
# lstm.bias_hh_l0 - First 5 weights: tensor([0.2503, 0.2273, 0.3029, 0.3207, 0.2178])
# fc.weight - First 5 weights: tensor([ 0.1333,  0.2189,  0.1285, -0.0518, -0.1717])
# fc.bias - First 5 weights: tensor([-0.2139, -0.0884, -0.0943, -0.2638, -0.1905])
# [None, None, None, None, None, None, None]
#
# DISCRIMINATOR Gradients within generator training (should stay the same):
# embedding.weight - First 5 weights: tensor([ 0.2777,  0.1662,  0.2462,  0.2507, -0.0435])
# lstm.weight_ih_l0 - First 5 weights: tensor([ 0.0598,  0.0248, -0.0499, -0.1158, -0.0085])
# lstm.weight_hh_l0 - First 5 weights: tensor([-0.0959,  0.1232,  0.0500, -0.0380, -0.0075])
# lstm.bias_ih_l0 - First 5 weights: tensor([-0.0016,  0.1155,  0.0114, -0.0879, -0.0215])
# lstm.bias_hh_l0 - First 5 weights: tensor([ 0.0412,  0.1166,  0.0933, -0.0810, -0.1092])
# fc.weight - First 5 weights: tensor([-0.0959,  0.0365, -0.0698,  0.1138,  0.0997])
# fc.bias - First 5 weights: tensor([0.0866])
# [0.3052859604358673, 11.368083953857422, 5.316651344299316, 1.0589452981948853, 1.0589451789855957, 1.9409189224243164, 0.45996183156967163]
